# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# seaborn==0.11.2
# pandas==1.3.5
# numpy==1.21.6
# matplotlib==3.2.2
# google==2.0.3

# %%
df = pd.read_csv('/content/drive/MyDrive/Đồ án biểu diễn (Dự báo giá chứng khoán)/dataset/VNM.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2021-12-01  20.879999  20.980000  20.750000  20.799999  20.696852  195600
# 1  2021-12-02  20.799999  20.850000  20.680000  20.719999  20.617249  296800
# 2  2021-12-03  20.500000  20.549999  20.280001  20.370001  20.268986  251000
# 3  2021-12-06  20.000000  20.049999  19.870001  20.010000  19.910770  502800
# 4  2021-12-07  20.379999  20.559999  20.320000  20.510000  20.408291  339700

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)

            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)

            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 10000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model,
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: 0.017000
# iter 20. reward: 0.027200
# iter 30. reward: 0.028600
# iter 40. reward: 0.031900
# iter 50. reward: 0.034500
# iter 60. reward: 0.031700
# iter 70. reward: 0.032500
# iter 80. reward: 0.036600
# iter 90. reward: 0.036100
# iter 100. reward: 0.037100
# iter 110. reward: 0.048400
# iter 120. reward: 0.046900
# iter 130. reward: 0.058600
# iter 140. reward: 0.059000
# iter 150. reward: 0.057700
# iter 160. reward: 0.056300
# iter 170. reward: 0.061000
# iter 180. reward: 0.060400
# iter 190. reward: 0.060800
# iter 200. reward: 0.056800
# iter 210. reward: 0.060000
# iter 220. reward: 0.061500
# iter 230. reward: 0.056200
# iter 240. reward: 0.065600
# iter 250. reward: 0.067600
# iter 260. reward: 0.061300
# iter 270. reward: 0.067600
# iter 280. reward: 0.060200
# iter 290. reward: 0.064900
# iter 300. reward: 0.066300
# iter 310. reward: 0.065000
# iter 320. reward: 0.064700
# iter 330. reward: 0.056900
# iter 340. reward: 0.047600
# iter 350. reward: 0.054400
# iter 360. reward: 0.050500
# iter 370. reward: 0.069000
# iter 380. reward: 0.075100
# iter 390. reward: 0.076800
# iter 400. reward: 0.070900
# iter 410. reward: 0.068100
# iter 420. reward: 0.075700
# iter 430. reward: 0.077800
# iter 440. reward: 0.078200
# iter 450. reward: 0.074100
# iter 460. reward: 0.082600
# iter 470. reward: 0.082700
# iter 480. reward: 0.085600
# iter 490. reward: 0.082000
# iter 500. reward: 0.073600
# time taken to train: 92.60401821136475 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 22: buy 1 unit at price 21.270000, total balance 9978.730000
# day 23, sell 1 unit at price 21.530001, investment 1.222384 %, total balance 10000.260001,
# day 28: buy 1 unit at price 21.059999, total balance 9979.200002
# day 29, sell 1 unit at price 21.090000, investment 0.142455 %, total balance 10000.290002,
# day 32: buy 1 unit at price 19.680000, total balance 9980.610002
# day 33, sell 1 unit at price 19.750000, investment 0.355691 %, total balance 10000.360002,
# day 36: buy 1 unit at price 19.120001, total balance 9981.240001
# day 37, sell 1 unit at price 19.480000, investment 1.882840 %, total balance 10000.720001,
# day 41: buy 1 unit at price 19.770000, total balance 9980.950001
# day 42, sell 1 unit at price 19.830000, investment 0.303490 %, total balance 10000.780001,
# day 43: buy 1 unit at price 19.889999, total balance 9980.890002
# day 44, sell 1 unit at price 19.760000, investment -0.653590 %, total balance 10000.650002,
# day 47: buy 1 unit at price 19.650000, total balance 9981.000002
# day 48, sell 1 unit at price 20.030001, investment 1.933847 %, total balance 10001.030003,
# day 51: buy 1 unit at price 19.400000, total balance 9981.630003
# day 52, sell 1 unit at price 19.650000, investment 1.288660 %, total balance 10001.280003,
# day 53: buy 1 unit at price 19.809999, total balance 9981.470004
# day 54, sell 1 unit at price 19.820000, investment 0.050485 %, total balance 10001.290004,
# day 55: buy 1 unit at price 19.790001, total balance 9981.500003
# day 56, sell 1 unit at price 19.639999, investment -0.757969 %, total balance 10001.140002,
# day 61: buy 1 unit at price 19.430000, total balance 9981.710002
# day 62, sell 1 unit at price 19.549999, investment 0.617597 %, total balance 10001.260001,
# day 69: buy 1 unit at price 18.530001, total balance 9982.730000
# day 70: buy 1 unit at price 18.200001, total balance 9964.529999
# day 71, sell 1 unit at price 18.400000, investment -0.701570 %, total balance 9982.929999,
# day 72, sell 1 unit at price 18.760000, investment 3.076917 %, total balance 10001.689999,
# day 77: buy 1 unit at price 19.219999, total balance 9982.470000
# day 78, sell 1 unit at price 19.200001, investment -0.104048 %, total balance 10001.670001,
# day 80: buy 1 unit at price 18.920000, total balance 9982.750001
# day 81, sell 1 unit at price 19.110001, investment 1.004234 %, total balance 10001.860002,
# day 91: buy 1 unit at price 18.559999, total balance 9983.300003
# day 92, sell 1 unit at price 18.750000, investment 1.023712 %, total balance 10002.050003,
# day 99: buy 1 unit at price 16.600000, total balance 9985.450003
# day 100, sell 1 unit at price 16.719999, investment 0.722886 %, total balance 10002.170002,
# day 113: buy 1 unit at price 15.230000, total balance 9986.940002
# day 114: buy 1 unit at price 14.960000, total balance 9971.980002
# day 115, sell 1 unit at price 15.650000, investment 2.757715 %, total balance 9987.630002,
# day 116: buy 1 unit at price 15.420000, total balance 9972.210002
# day 117, sell 1 unit at price 15.600000, investment 4.278075 %, total balance 9987.810002,
# day 118: buy 1 unit at price 15.480000, total balance 9972.330002
# day 120: buy 1 unit at price 15.400000, total balance 9956.930002
# day 121: buy 1 unit at price 15.710000, total balance 9941.220002
# day 123: buy 1 unit at price 15.900000, total balance 9925.320002
# day 124, sell 1 unit at price 16.040001, investment 4.020759 %, total balance 9941.360003,
# day 125, sell 1 unit at price 16.059999, investment 3.746764 %, total balance 9957.420002,
# day 126, sell 1 unit at price 16.020000, investment 4.025974 %, total balance 9973.440002,
# day 127, sell 1 unit at price 15.810000, investment 0.636537 %, total balance 9989.250002,
# day 128: buy 1 unit at price 15.800000, total balance 9973.450002
# day 129, sell 1 unit at price 15.900000, investment 0.000000 %, total balance 9989.350002,
# day 130, sell 1 unit at price 15.960000, investment 1.012658 %, total balance 10005.310002,
# day 131: buy 1 unit at price 15.930000, total balance 9989.380002
# day 132, sell 1 unit at price 15.650000, investment -1.757690 %, total balance 10005.030002,
# day 133: buy 1 unit at price 14.950000, total balance 9990.080002
# day 134, sell 1 unit at price 15.050000, investment 0.668896 %, total balance 10005.130002,
# day 138: buy 1 unit at price 14.540000, total balance 9990.590002
# day 139: buy 1 unit at price 14.450000, total balance 9976.140002
# day 140, sell 1 unit at price 14.650000, investment 0.756534 %, total balance 9990.790002,
# day 141, sell 1 unit at price 14.790000, investment 2.352941 %, total balance 10005.580002,
# day 143: buy 1 unit at price 14.820000, total balance 9990.760002
# day 144, sell 1 unit at price 14.710000, investment -0.742240 %, total balance 10005.470002,
# day 152: buy 1 unit at price 14.340000, total balance 9991.130002
# day 153, sell 1 unit at price 14.210000, investment -0.906555 %, total balance 10005.340002,
# day 156: buy 1 unit at price 14.270000, total balance 9991.070002
# day 157: buy 1 unit at price 14.520000, total balance 9976.550002
# day 158: buy 1 unit at price 14.610000, total balance 9961.940002
# day 159: buy 1 unit at price 14.660000, total balance 9947.280002
# day 160, sell 1 unit at price 14.500000, investment 1.611773 %, total balance 9961.780002,
# day 161, sell 1 unit at price 14.570000, investment 0.344353 %, total balance 9976.350002,
# day 162: buy 1 unit at price 14.340000, total balance 9962.010002
# day 163, sell 1 unit at price 14.610000, investment 0.000000 %, total balance 9976.620002,
# day 164, sell 1 unit at price 14.800000, investment 0.954980 %, total balance 9991.420002,
# day 165, sell 1 unit at price 14.730000, investment 2.719665 %, total balance 10006.150002,
# day 196: buy 1 unit at price 14.660000, total balance 9991.490002
# day 197, sell 1 unit at price 14.780000, investment 0.818554 %, total balance 10006.270002,
# day 200: buy 1 unit at price 14.370000, total balance 9991.900002
# day 201, sell 1 unit at price 14.400000, investment 0.208768 %, total balance 10006.300002,
# day 204: buy 1 unit at price 14.050000, total balance 9992.250002
# day 205, sell 1 unit at price 13.590000, investment -3.274021 %, total balance 10005.840002,
# day 208: buy 1 unit at price 13.080000, total balance 9992.760002
# day 209, sell 1 unit at price 13.300000, investment 1.681957 %, total balance 10006.060002,
# day 210: buy 1 unit at price 12.860000, total balance 9993.200002
# day 211, sell 1 unit at price 12.860000, investment 0.000000 %, total balance 10006.060002,
# day 212: buy 1 unit at price 13.020000, total balance 9993.040002
# day 213, sell 1 unit at price 12.670000, investment -2.688172 %, total balance 10005.710002,
# day 216: buy 1 unit at price 12.030000, total balance 9993.680002
# day 217: buy 1 unit at price 12.330000, total balance 9981.350002
# day 218, sell 1 unit at price 12.520000, investment 4.073150 %, total balance 9993.870002,
# day 219: buy 1 unit at price 12.280000, total balance 9981.590002
# day 220, sell 1 unit at price 12.330000, investment 0.000000 %, total balance 9993.920002,
# day 221, sell 1 unit at price 12.410000, investment 1.058632 %, total balance 10006.330002,
# day 225: buy 1 unit at price 11.360000, total balance 9994.970002
# day 227: buy 1 unit at price 11.470000, total balance 9983.500002
# day 228, sell 1 unit at price 11.770000, investment 3.609155 %, total balance 9995.270002,
# day 229, sell 1 unit at price 11.750000, investment 2.441151 %, total balance 10007.020002,
# day 235: buy 1 unit at price 11.050000, total balance 9995.970002
# day 236, sell 1 unit at price 11.250000, investment 1.809955 %, total balance 10007.220002,
# day 237: buy 1 unit at price 11.010000, total balance 9996.210002
# day 238, sell 1 unit at price 10.960000, investment -0.454133 %, total balance 10007.170002,
# day 244: buy 1 unit at price 11.380000, total balance 9995.790002
# day 245, sell 1 unit at price 11.170000, investment -1.845343 %, total balance 10006.960002,
# day 249: buy 1 unit at price 11.800000, total balance 9995.160002
# day 250, sell 1 unit at price 12.200000, investment 3.389831 %, total balance 10007.360002,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
