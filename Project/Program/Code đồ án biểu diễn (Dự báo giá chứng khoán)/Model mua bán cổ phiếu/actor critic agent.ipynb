# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('/content/drive/MyDrive/Đồ án biểu diễn (Dự báo giá chứng khoán)/dataset/VNM.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2021-12-01  20.879999  20.980000  20.750000  20.799999  20.696852  195600
# 1  2021-12-02  20.799999  20.850000  20.680000  20.719999  20.617249  296800
# 2  2021-12-03  20.500000  20.549999  20.280001  20.370001  20.268986  251000
# 3  2021-12-06  20.000000  20.049999  19.870001  20.010000  19.910770  502800
# 4  2021-12-07  20.379999  20.559999  20.320000  20.510000  20.408291  339700

# %%
from collections import deque
import random

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.compat.v1.variable_scope(name):
            self.X = tf.compat.v1.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            self.logits = tf.compat.v1.layers.dense(feed_actor, output_size)

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.compat.v1.variable_scope(name):
            self.X = tf.compat.v1.placeholder(tf.float32, (None, input_size))
            self.Y = tf.compat.v1.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.compat.v1.placeholder(tf.float32, (None, 1))
            feed_critic = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            feed_critic = tf.compat.v1.layers.dense(feed_critic, output_size, activation = tf.nn.relu) + self.Y
            feed_critic = tf.compat.v1.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.compat.v1.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(input_tensor=tf.square(self.REWARD - self.logits))
            self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate).minimize(self.cost)

class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE,
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(ys=self.critic.logits, xs=self.critic.Y)
        self.actor_critic_grad = tf.compat.v1.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(ys=self.actor.logits, xs=weights_actor, grad_ys=-self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.compat.v1.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())

    def _assign(self, from_name, to_name):
        from_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action

    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})

        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits,
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer],
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)

    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)

            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )

            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')

                action = self._select_action(state)
                next_state = self.get_state(t + 1)

                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]

                invest = ((starting_money - initial_money) / initial_money)

                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                state = next_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
tf.compat.v1.disable_eager_execution()

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size,
              window_size = window_size,
              trend = close,
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# <ipython-input-4-ad51f968250d>:8: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_actor = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
# <ipython-input-4-ad51f968250d>:9: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(feed_actor, output_size)
# <ipython-input-4-ad51f968250d>:17: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
# <ipython-input-4-ad51f968250d>:18: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(feed_critic, output_size, activation = tf.nn.relu) + self.Y
# <ipython-input-4-ad51f968250d>:19: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
# <ipython-input-4-ad51f968250d>:20: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(feed_critic, 1)
# epoch: 10, total rewards: -30.190004.3, cost: 0.000068, total money: 9845.659996
# epoch: 20, total rewards: -34.749999.3, cost: 0.000264, total money: 9851.950001
# epoch: 30, total rewards: -101.190007.3, cost: 0.000258, total money: 9394.159993
# epoch: 40, total rewards: -79.870002.3, cost: 0.000407, total money: 9733.679998
# epoch: 50, total rewards: -57.199999.3, cost: 0.000151, total money: 9668.330001
# epoch: 60, total rewards: -79.940005.3, cost: 0.000709, total money: 9624.129995
# epoch: 70, total rewards: -131.029992.3, cost: 0.000327, total money: 9335.330008
# epoch: 80, total rewards: -191.700005.3, cost: 0.000493, total money: 9016.989995
# epoch: 90, total rewards: -215.309998.3, cost: 0.001255, total money: 8772.870004
# epoch: 100, total rewards: -118.430005.3, cost: 0.000391, total money: 9439.969995
# epoch: 110, total rewards: -176.900003.3, cost: 0.003388, total money: 9185.729997
# epoch: 120, total rewards: -5.390001.3, cost: 0.000211, total money: 9982.409999
# epoch: 130, total rewards: -14.580003.3, cost: 0.000011, total money: 9985.419997
# epoch: 140, total rewards: -3.250004.3, cost: 0.000007, total money: 9996.749996
# epoch: 150, total rewards: -165.360011.3, cost: 0.011083, total money: 9186.889989
# epoch: 160, total rewards: -128.920001.3, cost: 0.003457, total money: 7971.829998
# epoch: 170, total rewards: -134.120004.3, cost: 0.004835, total money: 7781.989994
# epoch: 180, total rewards: -122.269993.3, cost: 0.004330, total money: 8050.580004
# epoch: 190, total rewards: -144.410005.3, cost: 0.005554, total money: 7872.679989
# epoch: 200, total rewards: -157.409995.3, cost: 0.004423, total money: 7592.250003

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 2: buy 1 unit at price 20.370001, total balance 9979.629999
# day 3: buy 1 unit at price 20.010000, total balance 9959.619999
# day 4, sell 1 unit at price 20.510000, investment 0.687280 %, total balance 9980.129999,
# day 5: buy 1 unit at price 20.700001, total balance 9959.429998
# day 6, sell 1 unit at price 20.850000, investment 4.197901 %, total balance 9980.279998,
# day 7, sell 1 unit at price 20.680000, investment -0.096623 %, total balance 10000.959998,
# day 8: buy 1 unit at price 20.680000, total balance 9980.279998
# day 9: buy 1 unit at price 20.690001, total balance 9959.589997
# day 10: buy 1 unit at price 20.740000, total balance 9938.849997
# day 11: buy 1 unit at price 20.709999, total balance 9918.139998
# day 12: buy 1 unit at price 20.770000, total balance 9897.369998
# day 13: buy 1 unit at price 20.600000, total balance 9876.769998
# day 14: buy 1 unit at price 20.879999, total balance 9855.889999
# day 15, sell 1 unit at price 20.990000, investment 1.499033 %, total balance 9876.879999,
# day 16: buy 1 unit at price 20.660000, total balance 9856.219999
# day 18, sell 1 unit at price 21.049999, investment 1.739961 %, total balance 9877.269998,
# day 19: buy 1 unit at price 21.010000, total balance 9856.259998
# day 20: buy 1 unit at price 21.260000, total balance 9834.999998
# day 21: buy 1 unit at price 21.240000, total balance 9813.759998
# day 22: buy 1 unit at price 21.270000, total balance 9792.489998
# day 23: buy 1 unit at price 21.530001, total balance 9770.959997
# day 24, sell 1 unit at price 21.490000, investment 3.616201 %, total balance 9792.449997,
# day 25, sell 1 unit at price 21.389999, investment 3.283438 %, total balance 9813.839996,
# day 26: buy 1 unit at price 21.400000, total balance 9792.439996
# day 27, sell 1 unit at price 21.200001, investment 2.070299 %, total balance 9813.639997,
# day 28: buy 1 unit at price 21.059999, total balance 9792.579998
# day 29: buy 1 unit at price 21.090000, total balance 9771.489998
# day 30: buy 1 unit at price 20.730000, total balance 9750.759998
# day 31: buy 1 unit at price 20.740000, total balance 9730.019998
# day 32: buy 1 unit at price 19.680000, total balance 9710.339998
# day 33, sell 1 unit at price 19.750000, investment -4.126214 %, total balance 9730.089998,
# day 34: buy 1 unit at price 19.910000, total balance 9710.179998
# day 35: buy 1 unit at price 19.840000, total balance 9690.339998
# day 36, sell 1 unit at price 19.120001, investment -8.429110 %, total balance 9709.459999,
# day 37: buy 1 unit at price 19.480000, total balance 9689.979999
# day 38: buy 1 unit at price 19.330000, total balance 9670.649999
# day 42: buy 1 unit at price 19.830000, total balance 9650.819999
# day 43: buy 1 unit at price 19.889999, total balance 9630.930000
# day 44: buy 1 unit at price 19.760000, total balance 9611.170000
# day 45: buy 1 unit at price 19.719999, total balance 9591.450001
# day 46: buy 1 unit at price 19.740000, total balance 9571.710001
# day 48: buy 1 unit at price 20.030001, total balance 9551.680000
# day 49, sell 1 unit at price 19.870001, investment -3.823809 %, total balance 9571.550001,
# day 50: buy 1 unit at price 19.620001, total balance 9551.930000
# day 51: buy 1 unit at price 19.400000, total balance 9532.530000
# day 53: buy 1 unit at price 19.809999, total balance 9512.720001
# day 54: buy 1 unit at price 19.820000, total balance 9492.900001
# day 55: buy 1 unit at price 19.790001, total balance 9473.110000
# day 56: buy 1 unit at price 19.639999, total balance 9453.470001
# day 57, sell 1 unit at price 19.680000, investment -6.330319 %, total balance 9473.150001,
# day 58: buy 1 unit at price 19.500000, total balance 9453.650001
# day 59: buy 1 unit at price 19.590000, total balance 9434.060001
# day 60: buy 1 unit at price 19.510000, total balance 9414.550001
# day 62: buy 1 unit at price 19.549999, total balance 9395.000002
# day 64: buy 1 unit at price 19.639999, total balance 9375.360003
# day 65: buy 1 unit at price 19.240000, total balance 9356.120003
# day 66: buy 1 unit at price 18.969999, total balance 9337.150004
# day 70: buy 1 unit at price 18.200001, total balance 9318.950003
# day 71, sell 1 unit at price 18.400000, investment -13.452493 %, total balance 9337.350003,
# day 72: buy 1 unit at price 18.760000, total balance 9318.590003
# day 73: buy 1 unit at price 18.620001, total balance 9299.970002
# day 75: buy 1 unit at price 19.190001, total balance 9280.780001
# day 76: buy 1 unit at price 19.270000, total balance 9261.510001
# day 77: buy 1 unit at price 19.219999, total balance 9242.290002
# day 78: buy 1 unit at price 19.200001, total balance 9223.090001
# day 79: buy 1 unit at price 19.150000, total balance 9203.940001
# day 80: buy 1 unit at price 18.920000, total balance 9185.020001
# day 82: buy 1 unit at price 19.000000, total balance 9166.020001
# day 83: buy 1 unit at price 18.870001, total balance 9147.150000
# day 84: buy 1 unit at price 19.190001, total balance 9127.959999
# day 85: buy 1 unit at price 19.450001, total balance 9108.509998
# day 86, sell 1 unit at price 19.270000, investment -9.274953 %, total balance 9127.779998,
# day 87: buy 1 unit at price 19.059999, total balance 9108.719999
# day 89: buy 1 unit at price 18.770000, total balance 9089.949999
# day 90: buy 1 unit at price 18.690001, total balance 9071.259998
# day 91: buy 1 unit at price 18.559999, total balance 9052.699999
# day 93: buy 1 unit at price 18.540001, total balance 9034.159998
# day 94: buy 1 unit at price 18.000000, total balance 9016.159998
# day 95: buy 1 unit at price 17.700001, total balance 8998.459997
# day 96: buy 1 unit at price 17.510000, total balance 8980.949997
# day 97: buy 1 unit at price 17.360001, total balance 8963.589996
# day 98, sell 1 unit at price 17.260000, investment -18.852844 %, total balance 8980.849996,
# day 99: buy 1 unit at price 16.600000, total balance 8964.249996
# day 100: buy 1 unit at price 16.719999, total balance 8947.529997
# day 101: buy 1 unit at price 16.959999, total balance 8930.569998
# day 102: buy 1 unit at price 16.900000, total balance 8913.669998
# day 103: buy 1 unit at price 17.040001, total balance 8896.629997
# day 104: buy 1 unit at price 17.100000, total balance 8879.529997
# day 105: buy 1 unit at price 17.219999, total balance 8862.309998
# day 106: buy 1 unit at price 17.059999, total balance 8845.249999
# day 107, sell 1 unit at price 16.860001, investment -21.690663 %, total balance 8862.110000,
# day 108: buy 1 unit at price 16.620001, total balance 8845.489999
# day 109: buy 1 unit at price 15.740000, total balance 8829.749999
# day 110: buy 1 unit at price 16.139999, total balance 8813.610000
# day 111: buy 1 unit at price 16.090000, total balance 8797.520000
# day 112: buy 1 unit at price 15.280000, total balance 8782.240000
# day 113, sell 1 unit at price 15.230000, investment -28.831776 %, total balance 8797.470000,
# day 114: buy 1 unit at price 14.960000, total balance 8782.510000
# day 116: buy 1 unit at price 15.420000, total balance 8767.090000
# day 117: buy 1 unit at price 15.600000, total balance 8751.490000
# day 118: buy 1 unit at price 15.480000, total balance 8736.010000
# day 120: buy 1 unit at price 15.400000, total balance 8720.610000
# day 121: buy 1 unit at price 15.710000, total balance 8704.900000
# day 122: buy 1 unit at price 15.740000, total balance 8689.160000
# day 123: buy 1 unit at price 15.900000, total balance 8673.260000
# day 128: buy 1 unit at price 15.800000, total balance 8657.460000
# day 129: buy 1 unit at price 15.900000, total balance 8641.560000
# day 130: buy 1 unit at price 15.960000, total balance 8625.600000
# day 131: buy 1 unit at price 15.930000, total balance 8609.670000
# day 132: buy 1 unit at price 15.650000, total balance 8594.020000
# day 133, sell 1 unit at price 14.950000, investment -29.012342 %, total balance 8608.970000,
# day 134, sell 1 unit at price 15.050000, investment -28.639165 %, total balance 8624.020000,
# day 135: buy 1 unit at price 14.980000, total balance 8609.040000
# day 138: buy 1 unit at price 14.540000, total balance 8594.500000
# day 139: buy 1 unit at price 14.450000, total balance 8580.050000
# day 140: buy 1 unit at price 14.650000, total balance 8565.400000
# day 141, sell 1 unit at price 14.790000, investment -28.654124 %, total balance 8580.190000,
# day 142: buy 1 unit at price 14.810000, total balance 8565.380000
# day 144: buy 1 unit at price 14.710000, total balance 8550.670000
# day 145: buy 1 unit at price 14.400000, total balance 8536.270000
# day 147: buy 1 unit at price 14.090000, total balance 8522.180000
# day 148: buy 1 unit at price 13.800000, total balance 8508.380000
# day 149: buy 1 unit at price 14.160000, total balance 8494.220000
# day 150: buy 1 unit at price 14.280000, total balance 8479.940000
# day 151: buy 1 unit at price 14.180000, total balance 8465.760000
# day 152: buy 1 unit at price 14.340000, total balance 8451.420000
# day 153: buy 1 unit at price 14.210000, total balance 8437.210000
# day 154, sell 1 unit at price 14.340000, investment -30.858245 %, total balance 8451.550000,
# day 155: buy 1 unit at price 14.430000, total balance 8437.120000
# day 156: buy 1 unit at price 14.270000, total balance 8422.850000
# day 157: buy 1 unit at price 14.520000, total balance 8408.330000
# day 158: buy 1 unit at price 14.610000, total balance 8393.720000
# day 160: buy 1 unit at price 14.500000, total balance 8379.220000
# day 161: buy 1 unit at price 14.570000, total balance 8364.650000
# day 162: buy 1 unit at price 14.340000, total balance 8350.310000
# day 163: buy 1 unit at price 14.610000, total balance 8335.700000
# day 164: buy 1 unit at price 14.800000, total balance 8320.900000
# day 165: buy 1 unit at price 14.730000, total balance 8306.170000
# day 166: buy 1 unit at price 15.030000, total balance 8291.140000
# day 167: buy 1 unit at price 15.060000, total balance 8276.080000
# day 168: buy 1 unit at price 15.220000, total balance 8260.860000
# day 169: buy 1 unit at price 15.260000, total balance 8245.600000
# day 170: buy 1 unit at price 15.290000, total balance 8230.310000
# day 171: buy 1 unit at price 15.360000, total balance 8214.950000
# day 172: buy 1 unit at price 15.420000, total balance 8199.530000
# day 173: buy 1 unit at price 15.510000, total balance 8184.020000
# day 174, sell 1 unit at price 15.430000, investment -21.595528 %, total balance 8199.450000,
# day 175: buy 1 unit at price 15.670000, total balance 8183.780000
# day 176: buy 1 unit at price 15.710000, total balance 8168.070000
# day 177: buy 1 unit at price 15.680000, total balance 8152.390000
# day 178: buy 1 unit at price 15.740000, total balance 8136.650000
# day 179: buy 1 unit at price 15.640000, total balance 8121.010000
# day 180: buy 1 unit at price 15.450000, total balance 8105.560000
# day 181: buy 1 unit at price 15.280000, total balance 8090.280000
# day 182: buy 1 unit at price 15.470000, total balance 8074.810000
# day 183, sell 1 unit at price 15.600000, investment -21.647413 %, total balance 8090.410000,
# day 184: buy 1 unit at price 15.780000, total balance 8074.630000
# day 185: buy 1 unit at price 15.340000, total balance 8059.290000
# day 186, sell 1 unit at price 15.240000, investment -23.185484 %, total balance 8074.530000,
# day 187: buy 1 unit at price 15.170000, total balance 8059.360000
# day 188: buy 1 unit at price 15.330000, total balance 8044.030000
# day 189, sell 1 unit at price 15.240000, investment -21.765914 %, total balance 8059.270000,
# day 190: buy 1 unit at price 15.170000, total balance 8044.100000
# day 191: buy 1 unit at price 15.050000, total balance 8029.050000
# day 195: buy 1 unit at price 15.150000, total balance 8013.900000
# day 196: buy 1 unit at price 14.660000, total balance 7999.240000
# day 197, sell 1 unit at price 14.780000, investment -23.538541 %, total balance 8014.020000,
# day 198: buy 1 unit at price 14.650000, total balance 7999.370000
# day 199: buy 1 unit at price 14.510000, total balance 7984.860000
# day 200: buy 1 unit at price 14.370000, total balance 7970.490000
# day 201: buy 1 unit at price 14.400000, total balance 7956.090000
# day 202: buy 1 unit at price 14.350000, total balance 7941.740000
# day 203: buy 1 unit at price 14.200000, total balance 7927.540000
# day 204, sell 1 unit at price 14.050000, investment -29.147756 %, total balance 7941.590000,
# day 205: buy 1 unit at price 13.590000, total balance 7928.000000
# day 206: buy 1 unit at price 13.550000, total balance 7914.450000
# day 207: buy 1 unit at price 13.500000, total balance 7900.950000
# day 208: buy 1 unit at price 13.080000, total balance 7887.870000
# day 209: buy 1 unit at price 13.300000, total balance 7874.570000
# day 210: buy 1 unit at price 12.860000, total balance 7861.710000
# day 211: buy 1 unit at price 12.860000, total balance 7848.850000
# day 212, sell 1 unit at price 13.020000, investment -34.539967 %, total balance 7861.870000,
# day 213: buy 1 unit at price 12.670000, total balance 7849.200000
# day 214: buy 1 unit at price 12.410000, total balance 7836.790000
# day 215: buy 1 unit at price 12.420000, total balance 7824.370000
# day 216: buy 1 unit at price 12.030000, total balance 7812.340000
# day 217: buy 1 unit at price 12.330000, total balance 7800.010000
# day 218: buy 1 unit at price 12.520000, total balance 7787.490000
# day 219: buy 1 unit at price 12.280000, total balance 7775.210000
# day 220: buy 1 unit at price 12.330000, total balance 7762.880000
# day 221: buy 1 unit at price 12.410000, total balance 7750.470000
# day 222: buy 1 unit at price 12.220000, total balance 7738.250000
# day 223: buy 1 unit at price 12.130000, total balance 7726.120000
# day 224, sell 1 unit at price 11.870000, investment -39.929150 %, total balance 7737.990000,
# day 225: buy 1 unit at price 11.360000, total balance 7726.630000
# day 226: buy 1 unit at price 11.350000, total balance 7715.280000
# day 227: buy 1 unit at price 11.470000, total balance 7703.810000
# day 228, sell 1 unit at price 11.770000, investment -40.314399 %, total balance 7715.580000,
# day 229: buy 1 unit at price 11.750000, total balance 7703.830000
# day 230: buy 1 unit at price 11.680000, total balance 7692.150000
# day 231: buy 1 unit at price 11.540000, total balance 7680.610000
# day 232: buy 1 unit at price 11.480000, total balance 7669.130000
# day 234: buy 1 unit at price 11.340000, total balance 7657.790000
# day 235: buy 1 unit at price 11.050000, total balance 7646.740000
# day 237, sell 1 unit at price 11.010000, investment -44.224924 %, total balance 7657.750000,
# day 238: buy 1 unit at price 10.960000, total balance 7646.790000
# day 239, sell 1 unit at price 11.210000, investment -44.033952 %, total balance 7658.000000,
# day 240: buy 1 unit at price 10.940000, total balance 7647.060000
# day 241: buy 1 unit at price 10.900000, total balance 7636.160000
# day 242: buy 1 unit at price 11.260000, total balance 7624.900000
# day 243: buy 1 unit at price 11.480000, total balance 7613.420000
# day 245: buy 1 unit at price 11.170000, total balance 7602.250000
# day 246: buy 1 unit at price 11.150000, total balance 7591.100000
# day 247: buy 1 unit at price 11.120000, total balance 7579.980000
# day 249: buy 1 unit at price 11.800000, total balance 7568.180000
# day 250: buy 1 unit at price 12.200000, total balance 7555.980000

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
