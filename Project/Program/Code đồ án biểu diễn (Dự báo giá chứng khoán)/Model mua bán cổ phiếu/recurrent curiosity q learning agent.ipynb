# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('/content/drive/MyDrive/Đồ án biểu diễn (Dự báo giá chứng khoán)/dataset/VNM.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2021-12-01  20.879999  20.980000  20.750000  20.799999  20.696852  195600
# 1  2021-12-02  20.799999  20.850000  20.680000  20.719999  20.617249  296800
# 2  2021-12-03  20.500000  20.549999  20.280001  20.370001  20.268986  251000
# 3  2021-12-06  20.000000  20.049999  19.870001  20.010000  19.910770  502800
# 4  2021-12-07  20.379999  20.559999  20.320000  20.510000  20.408291  339700

# %%
from collections import deque
import random

class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 128
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.X = tf.compat.v1.placeholder(tf.float32, (None, None, self.state_size))
        self.Y = tf.compat.v1.placeholder(tf.float32, (None, None, self.state_size))
        self.hidden_layer = tf.compat.v1.placeholder(tf.float32, (None, 2 * self.LAYER_SIZE))
        self.ACTION = tf.compat.v1.placeholder(tf.float32, (None))
        self.REWARD = tf.compat.v1.placeholder(tf.float32, (None))
        self.batch_size = tf.shape(input=self.ACTION)[0]
        self.seq_len = tf.shape(input=self.X)[1]

        with tf.compat.v1.variable_scope('curiosity_model'):
            action = tf.reshape(self.ACTION, (-1,1,1))
            repeat_action = tf.tile(action, [1,self.seq_len,1])
            state_action = tf.concat([self.X, repeat_action], axis=-1)
            save_state = tf.identity(self.Y)
            cell = tf.compat.v1.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
            self.rnn,last_state = tf.compat.v1.nn.dynamic_rnn(inputs=state_action,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            self.curiosity_logits = tf.compat.v1.layers.dense(self.rnn[:,-1], self.state_size)
            self.curiosity_cost = tf.reduce_sum(input_tensor=tf.square(save_state[:,-1] - self.curiosity_logits), axis=1)

            self.curiosity_optimizer = tf.compat.v1.train.RMSPropOptimizer(self.LEARNING_RATE)\
            .minimize(tf.reduce_mean(input_tensor=self.curiosity_cost))

        total_reward = tf.add(self.curiosity_cost, self.REWARD)

        with tf.compat.v1.variable_scope("q_model"):
            with tf.compat.v1.variable_scope("eval_net"):
                cell = tf.compat.v1.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
                rnn,self.last_state = tf.compat.v1.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
                self.logits = tf.compat.v1.layers.dense(rnn[:,-1], self.OUTPUT_SIZE)

            with tf.compat.v1.variable_scope("target_net"):
                cell = tf.compat.v1.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
                rnn,last_state = tf.compat.v1.nn.dynamic_rnn(inputs=self.Y,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
                y_q = tf.compat.v1.layers.dense(rnn[:,-1], self.OUTPUT_SIZE)

            q_target = total_reward + self.GAMMA * tf.reduce_max(input_tensor=y_q, axis=1)
            action = tf.cast(self.ACTION, tf.int32)
            action_indices = tf.stack([tf.range(self.batch_size, dtype=tf.int32), action], axis=1)
            q = tf.gather_nd(params=self.logits, indices=action_indices)
            self.cost = tf.compat.v1.losses.mean_squared_error(labels=q_target, predictions=q)
            self.optimizer = tf.compat.v1.train.RMSPropOptimizer(self.LEARNING_RATE).minimize(
            self.cost, var_list=tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, "q_model/eval_net"))

        t_params = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.GLOBAL_VARIABLES, scope='q_model/target_net')
        e_params = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.GLOBAL_VARIABLES, scope='q_model/eval_net')
        self.target_replace_op = [tf.compat.v1.assign(t, e) for t, e in zip(t_params, e_params)]

        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())

    def _memorize(self, state, action, reward, new_state, done, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, done, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        actions = np.array([a[1] for a in replay])
        rewards = np.array([a[2] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.target_replace_op)

        cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict = {
            self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards,
            self.hidden_layer: init_values
        })

        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.curiosity_optimizer, feed_dict = {
                self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards,
                self.hidden_layer: init_values
            })
        return cost

    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):

            if np.random.rand() < self.EPSILON:
                action = np.random.randint(self.OUTPUT_SIZE)
            else:
                action, last_state = self.sess.run([self.logits,
                                                  self.last_state],
                                                  feed_dict={self.X:[self.INITIAL_FEATURES],
                                                             self.hidden_layer:init_value})
                action, init_value = np.argmax(action[0]), last_state

            next_state = self.get_state(t + 1)

            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )

            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.logits,
                                                  self.last_state],
                                                  feed_dict={self.X:[self.INITIAL_FEATURES],
                                                             self.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state

                next_state = self.get_state(t + 1)

                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]

                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state,
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
tf.compat.v1.disable_eager_execution()

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size,
              window_size = window_size,
              trend = close,
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:<keras.layers.rnn.legacy_cells.LSTMCell object at 0x7fc4a91e0950>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:From <ipython-input-4-e8d66499791e>:43: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/layers/rnn/legacy_cells.py:958: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/rmsprop.py:188: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:54: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:<keras.layers.rnn.legacy_cells.LSTMCell object at 0x7fc4a6e350d0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:61: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:<keras.layers.rnn.legacy_cells.LSTMCell object at 0x7fc4b02b4f90>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:65: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
# epoch: 10, total rewards: -32.350000.3, cost: 0.208153, total money: 9910.900000
# epoch: 20, total rewards: -19.810003.3, cost: 0.545416, total money: 9968.619997
# epoch: 30, total rewards: -16.009999.3, cost: 0.135070, total money: 9961.700001
# epoch: 40, total rewards: -10.950009.3, cost: 0.777987, total money: 9966.499991
# epoch: 50, total rewards: -60.009983.3, cost: 0.175094, total money: 9811.710017
# epoch: 60, total rewards: -24.339998.3, cost: 0.450762, total money: 9940.770002
# epoch: 70, total rewards: -57.889999.3, cost: 0.370014, total money: 9733.070001
# epoch: 80, total rewards: -32.959989.3, cost: 0.619236, total money: 9899.500011
# epoch: 90, total rewards: -54.660004.3, cost: 0.511524, total money: 9841.659996
# epoch: 100, total rewards: -20.940003.3, cost: 0.438672, total money: 9979.059997
# epoch: 110, total rewards: -58.869999.3, cost: 0.149066, total money: 9672.000001
# epoch: 120, total rewards: -20.430004.3, cost: 0.532310, total money: 9979.569996
# epoch: 130, total rewards: -107.829995.3, cost: 0.854866, total money: 9430.370005
# epoch: 140, total rewards: -77.589993.3, cost: 1.036779, total money: 9763.930007
# epoch: 150, total rewards: -169.160001.3, cost: 0.374608, total money: 9304.239999
# epoch: 160, total rewards: -132.839995.3, cost: 0.430466, total money: 9867.160005
# epoch: 170, total rewards: -158.990007.3, cost: 0.220278, total money: 9537.559993
# epoch: 180, total rewards: -52.159994.3, cost: 0.517273, total money: 9912.030006
# epoch: 190, total rewards: -22.769999.3, cost: 0.366430, total money: 9953.230001
# epoch: 200, total rewards: -12.050002.3, cost: 0.629116, total money: 9987.949998

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 20.719999, total balance 9979.280001
# day 2: buy 1 unit at price 20.370001, total balance 9958.910000
# day 3: buy 1 unit at price 20.010000, total balance 9938.900000
# day 4: buy 1 unit at price 20.510000, total balance 9918.390000
# day 5: buy 1 unit at price 20.700001, total balance 9897.689999
# day 7: buy 1 unit at price 20.680000, total balance 9877.009999
# day 8: buy 1 unit at price 20.680000, total balance 9856.329999
# day 9: buy 1 unit at price 20.690001, total balance 9835.639998
# day 10, sell 1 unit at price 20.740000, investment 0.096530 %, total balance 9856.379998,
# day 11: buy 1 unit at price 20.709999, total balance 9835.669999
# day 12: buy 1 unit at price 20.770000, total balance 9814.899999
# day 13: buy 1 unit at price 20.600000, total balance 9794.299999
# day 14: buy 1 unit at price 20.879999, total balance 9773.420000
# day 15, sell 1 unit at price 20.990000, investment 3.043687 %, total balance 9794.410000,
# day 16: buy 1 unit at price 20.660000, total balance 9773.750000
# day 17: buy 1 unit at price 21.010000, total balance 9752.740000
# day 18: buy 1 unit at price 21.049999, total balance 9731.690001
# day 20: buy 1 unit at price 21.260000, total balance 9710.430001
# day 21: buy 1 unit at price 21.240000, total balance 9689.190001
# day 22: buy 1 unit at price 21.270000, total balance 9667.920001
# day 23: buy 1 unit at price 21.530001, total balance 9646.390000
# day 24: buy 1 unit at price 21.490000, total balance 9624.900000
# day 25: buy 1 unit at price 21.389999, total balance 9603.510001
# day 26: buy 1 unit at price 21.400000, total balance 9582.110001
# day 28: buy 1 unit at price 21.059999, total balance 9561.050002
# day 29: buy 1 unit at price 21.090000, total balance 9539.960002
# day 30: buy 1 unit at price 20.730000, total balance 9519.230002
# day 31: buy 1 unit at price 20.740000, total balance 9498.490002
# day 32: buy 1 unit at price 19.680000, total balance 9478.810002
# day 36, sell 1 unit at price 19.120001, investment -4.447771 %, total balance 9497.930003,
# day 37: buy 1 unit at price 19.480000, total balance 9478.450003
# day 39, sell 1 unit at price 19.370001, investment -5.558259 %, total balance 9497.820004,
# day 41: buy 1 unit at price 19.770000, total balance 9478.050004
# day 42: buy 1 unit at price 19.830000, total balance 9458.220004
# day 43, sell 1 unit at price 19.889999, investment -3.913053 %, total balance 9478.110003,
# day 44: buy 1 unit at price 19.760000, total balance 9458.350003
# day 45: buy 1 unit at price 19.719999, total balance 9438.630004
# day 52: buy 1 unit at price 19.650000, total balance 9418.980004
# day 53: buy 1 unit at price 19.809999, total balance 9399.170005
# day 55: buy 1 unit at price 19.790001, total balance 9379.380004
# day 56, sell 1 unit at price 19.639999, investment -5.029018 %, total balance 9399.020003,
# day 57: buy 1 unit at price 19.680000, total balance 9379.340003
# day 58: buy 1 unit at price 19.500000, total balance 9359.840003
# day 59: buy 1 unit at price 19.590000, total balance 9340.250003
# day 60: buy 1 unit at price 19.510000, total balance 9320.740003
# day 61: buy 1 unit at price 19.430000, total balance 9301.310003
# day 62, sell 1 unit at price 19.549999, investment -5.464221 %, total balance 9320.860002,
# day 64, sell 1 unit at price 19.639999, investment -5.074925 %, total balance 9340.500001,
# day 67, sell 1 unit at price 19.120001, investment -7.677441 %, total balance 9359.620002,
# day 68: buy 1 unit at price 18.969999, total balance 9340.650003
# day 70, sell 1 unit at price 18.200001, investment -12.373611 %, total balance 9358.850004,
# day 71: buy 1 unit at price 18.400000, total balance 9340.450004
# day 72, sell 1 unit at price 18.760000, investment -8.932039 %, total balance 9359.210004,
# day 74: buy 1 unit at price 18.850000, total balance 9340.360004
# day 76, sell 1 unit at price 19.270000, investment -7.710724 %, total balance 9359.630004,
# day 77: buy 1 unit at price 19.219999, total balance 9340.410005
# day 78, sell 1 unit at price 19.200001, investment -7.066791 %, total balance 9359.610006,
# day 79: buy 1 unit at price 19.150000, total balance 9340.460006
# day 80: buy 1 unit at price 18.920000, total balance 9321.540006
# day 81, sell 1 unit at price 19.110001, investment -9.043308 %, total balance 9340.650007,
# day 82: buy 1 unit at price 19.000000, total balance 9321.650007
# day 83, sell 1 unit at price 18.870001, investment -10.356286 %, total balance 9340.520008,
# day 84, sell 1 unit at price 19.190001, investment -9.736590 %, total balance 9359.710009,
# day 85, sell 1 unit at price 19.450001, investment -8.427491 %, total balance 9379.160010,
# day 86, sell 1 unit at price 19.270000, investment -9.402915 %, total balance 9398.430010,
# day 88, sell 1 unit at price 18.990000, investment -11.797496 %, total balance 9417.420010,
# day 89, sell 1 unit at price 18.770000, investment -12.657050 %, total balance 9436.190010,
# day 90, sell 1 unit at price 18.690001, investment -12.622712 %, total balance 9454.880011,
# day 91, sell 1 unit at price 18.559999, investment -13.271033 %, total balance 9473.440010,
# day 92: buy 1 unit at price 18.750000, total balance 9454.690010
# day 93, sell 1 unit at price 18.540001, investment -11.965803 %, total balance 9473.230011,
# day 94: buy 1 unit at price 18.000000, total balance 9455.230011
# day 95, sell 1 unit at price 17.700001, investment -16.073964 %, total balance 9472.930012,
# day 96: buy 1 unit at price 17.510000, total balance 9455.420012
# day 97, sell 1 unit at price 17.360001, investment -16.256628 %, total balance 9472.780013,
# day 98, sell 1 unit at price 17.260000, investment -16.779171 %, total balance 9490.040013,
# day 99, sell 1 unit at price 16.600000, investment -15.650407 %, total balance 9506.640013,
# day 100, sell 1 unit at price 16.719999, investment -14.168383 %, total balance 9523.360012,
# day 101, sell 1 unit at price 16.959999, investment -14.213460 %, total balance 9540.320011,
# day 102: buy 1 unit at price 16.900000, total balance 9523.420011
# day 105, sell 1 unit at price 17.219999, investment -13.161881 %, total balance 9540.640010,
# day 106, sell 1 unit at price 17.059999, investment -13.663973 %, total balance 9557.700009,
# day 107, sell 1 unit at price 16.860001, investment -14.503033 %, total balance 9574.560010,
# day 108, sell 1 unit at price 16.620001, investment -15.419842 %, total balance 9591.180011,
# day 109, sell 1 unit at price 15.740000, investment -20.545175 %, total balance 9606.920011,
# day 110, sell 1 unit at price 16.139999, investment -18.443668 %, total balance 9623.060010,
# day 111: buy 1 unit at price 16.090000, total balance 9606.970010
# day 113, sell 1 unit at price 15.230000, investment -22.611789 %, total balance 9622.200010,
# day 114: buy 1 unit at price 14.960000, total balance 9607.240010
# day 115: buy 1 unit at price 15.650000, total balance 9591.590010
# day 117, sell 1 unit at price 15.600000, investment -20.000000 %, total balance 9607.190010,
# day 118: buy 1 unit at price 15.480000, total balance 9591.710010
# day 119: buy 1 unit at price 15.310000, total balance 9576.400010
# day 120: buy 1 unit at price 15.400000, total balance 9561.000010
# day 121, sell 1 unit at price 15.710000, investment -19.806023 %, total balance 9576.710010,
# day 122, sell 1 unit at price 15.740000, investment -19.323424 %, total balance 9592.450010,
# day 124, sell 1 unit at price 16.040001, investment -17.447241 %, total balance 9608.490011,
# day 125: buy 1 unit at price 16.059999, total balance 9592.430012
# day 127, sell 1 unit at price 15.810000, investment -16.657876 %, total balance 9608.240012,
# day 128: buy 1 unit at price 15.800000, total balance 9592.440012
# day 129: buy 1 unit at price 15.900000, total balance 9576.540012
# day 130, sell 1 unit at price 15.960000, investment -13.260870 %, total balance 9592.500012,
# day 132, sell 1 unit at price 15.650000, investment -16.976127 %, total balance 9608.150012,
# day 133, sell 1 unit at price 14.950000, investment -22.216437 %, total balance 9623.100012,
# day 135: buy 1 unit at price 14.980000, total balance 9608.120012
# day 136, sell 1 unit at price 14.890000, investment -22.245431 %, total balance 9623.010012,
# day 137, sell 1 unit at price 14.820000, investment -21.670190 %, total balance 9637.830012,
# day 138: buy 1 unit at price 14.540000, total balance 9623.290012
# day 139, sell 1 unit at price 14.450000, investment -23.947368 %, total balance 9637.740012,
# day 141, sell 1 unit at price 14.790000, investment -21.120000 %, total balance 9652.530012,
# day 143, sell 1 unit at price 14.820000, investment -17.666667 %, total balance 9667.350012,
# day 144, sell 1 unit at price 14.710000, investment -15.990862 %, total balance 9682.060012,
# day 145, sell 1 unit at price 14.400000, investment -14.792899 %, total balance 9696.460012,
# day 146, sell 1 unit at price 14.480000, investment -10.006215 %, total balance 9710.940012,
# day 147, sell 1 unit at price 14.090000, investment -5.815508 %, total balance 9725.030012,
# day 148, sell 1 unit at price 13.800000, investment -11.821086 %, total balance 9738.830012,
# day 149, sell 1 unit at price 14.160000, investment -8.527132 %, total balance 9752.990012,
# day 151, sell 1 unit at price 14.180000, investment -7.380797 %, total balance 9767.170012,
# day 152, sell 1 unit at price 14.340000, investment -6.883117 %, total balance 9781.510012,
# day 153, sell 1 unit at price 14.210000, investment -11.519297 %, total balance 9795.720012,
# day 154, sell 1 unit at price 14.340000, investment -9.240506 %, total balance 9810.060012,
# day 157: buy 1 unit at price 14.520000, total balance 9795.540012
# day 160: buy 1 unit at price 14.500000, total balance 9781.040012
# day 161: buy 1 unit at price 14.570000, total balance 9766.470012
# day 162: buy 1 unit at price 14.340000, total balance 9752.130012
# day 163, sell 1 unit at price 14.610000, investment -8.113208 %, total balance 9766.740012,
# day 164: buy 1 unit at price 14.800000, total balance 9751.940012
# day 165, sell 1 unit at price 14.730000, investment -1.668892 %, total balance 9766.670012,
# day 166: buy 1 unit at price 15.030000, total balance 9751.640012
# day 167, sell 1 unit at price 15.060000, investment 3.576341 %, total balance 9766.700012,
# day 168: buy 1 unit at price 15.220000, total balance 9751.480012
# day 169: buy 1 unit at price 15.260000, total balance 9736.220012
# day 170: buy 1 unit at price 15.290000, total balance 9720.930012
# day 171: buy 1 unit at price 15.360000, total balance 9705.570012
# day 172, sell 1 unit at price 15.420000, investment 6.198347 %, total balance 9720.990012,
# day 173, sell 1 unit at price 15.510000, investment 6.965517 %, total balance 9736.500012,
# day 174, sell 1 unit at price 15.430000, investment 5.902539 %, total balance 9751.930012,
# day 176: buy 1 unit at price 15.710000, total balance 9736.220012
# day 177, sell 1 unit at price 15.680000, investment 9.344491 %, total balance 9751.900012,
# day 178: buy 1 unit at price 15.740000, total balance 9736.160012
# day 179: buy 1 unit at price 15.640000, total balance 9720.520012
# day 181, sell 1 unit at price 15.280000, investment 3.243243 %, total balance 9735.800012,
# day 182: buy 1 unit at price 15.470000, total balance 9720.330012
# day 183: buy 1 unit at price 15.600000, total balance 9704.730012
# day 184: buy 1 unit at price 15.780000, total balance 9688.950012
# day 185, sell 1 unit at price 15.340000, investment 2.062542 %, total balance 9704.290012,
# day 186, sell 1 unit at price 15.240000, investment 0.131406 %, total balance 9719.530012,
# day 188, sell 1 unit at price 15.330000, investment 0.458716 %, total balance 9734.860012,
# day 189, sell 1 unit at price 15.240000, investment -0.327011 %, total balance 9750.100012,
# day 190: buy 1 unit at price 15.170000, total balance 9734.930012
# day 192, sell 1 unit at price 14.880000, investment -3.125000 %, total balance 9749.810012,
# day 193, sell 1 unit at price 14.860000, investment -5.410567 %, total balance 9764.670012,
# day 195: buy 1 unit at price 15.150000, total balance 9749.520012
# day 196: buy 1 unit at price 14.660000, total balance 9734.860012
# day 197, sell 1 unit at price 14.780000, investment -6.099111 %, total balance 9749.640012,
# day 198, sell 1 unit at price 14.650000, investment -6.329923 %, total balance 9764.290012,
# day 199, sell 1 unit at price 14.510000, investment -6.205559 %, total balance 9778.800012,
# day 200, sell 1 unit at price 14.370000, investment -7.884615 %, total balance 9793.170012,
# day 201, sell 1 unit at price 14.400000, investment -8.745247 %, total balance 9807.570012,
# day 202, sell 1 unit at price 14.350000, investment -5.405405 %, total balance 9821.920012,
# day 203, sell 1 unit at price 14.200000, investment -6.270627 %, total balance 9836.120012,
# day 204, sell 1 unit at price 14.050000, investment -4.160982 %, total balance 9850.170012,
# day 216: buy 1 unit at price 12.030000, total balance 9838.140012
# day 217, sell 1 unit at price 12.330000, investment 2.493766 %, total balance 9850.470012,
# day 221: buy 1 unit at price 12.410000, total balance 9838.060012
# day 222: buy 1 unit at price 12.220000, total balance 9825.840012
# day 223: buy 1 unit at price 12.130000, total balance 9813.710012
# day 224: buy 1 unit at price 11.870000, total balance 9801.840012
# day 225: buy 1 unit at price 11.360000, total balance 9790.480012
# day 226: buy 1 unit at price 11.350000, total balance 9779.130012
# day 228, sell 1 unit at price 11.770000, investment -5.157131 %, total balance 9790.900012,
# day 231, sell 1 unit at price 11.540000, investment -5.564648 %, total balance 9802.440012,
# day 232, sell 1 unit at price 11.480000, investment -5.358615 %, total balance 9813.920012,
# day 235, sell 1 unit at price 11.050000, investment -6.908172 %, total balance 9824.970012,
# day 236, sell 1 unit at price 11.250000, investment -0.968310 %, total balance 9836.220012,
# day 237: buy 1 unit at price 11.010000, total balance 9825.210012
# day 238: buy 1 unit at price 10.960000, total balance 9814.250012
# day 239, sell 1 unit at price 11.210000, investment -1.233480 %, total balance 9825.460012,
# day 240, sell 1 unit at price 10.940000, investment -0.635786 %, total balance 9836.400012,
# day 241, sell 1 unit at price 10.900000, investment -0.547445 %, total balance 9847.300012,
# day 242: buy 1 unit at price 11.260000, total balance 9836.040012
# day 243, sell 1 unit at price 11.480000, investment 1.953819 %, total balance 9847.520012,
# day 244: buy 1 unit at price 11.380000, total balance 9836.140012
# day 246, sell 1 unit at price 11.150000, investment -2.021090 %, total balance 9847.290012,
# day 247: buy 1 unit at price 11.120000, total balance 9836.170012
# day 248: buy 1 unit at price 11.570000, total balance 9824.600012
# day 249, sell 1 unit at price 11.800000, investment 6.115108 %, total balance 9836.400012,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
