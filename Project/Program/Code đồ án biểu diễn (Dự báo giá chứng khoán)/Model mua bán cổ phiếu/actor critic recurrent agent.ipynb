# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('/content/drive/MyDrive/Đồ án biểu diễn (Dự báo giá chứng khoán)/dataset/VNM.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2021-12-01  20.879999  20.980000  20.750000  20.799999  20.696852  195600
# 1  2021-12-02  20.799999  20.850000  20.680000  20.719999  20.617249  296800
# 2  2021-12-03  20.500000  20.549999  20.280001  20.370001  20.268986  251000
# 3  2021-12-06  20.000000  20.049999  19.870001  20.010000  19.910770  502800
# 4  2021-12-07  20.379999  20.559999  20.320000  20.510000  20.408291  339700

# %%
from collections import deque
import random

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.compat.v1.variable_scope(name):
            self.X = tf.compat.v1.placeholder(tf.float32, (None, None, input_size))
            self.hidden_layer = tf.compat.v1.placeholder(tf.float32, (None, 2 * size_layer))
            cell = tf.compat.v1.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)
            self.rnn,self.last_state = tf.compat.v1.nn.dynamic_rnn(inputs=self.X, cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            self.logits = tf.compat.v1.layers.dense(self.rnn[:,-1], output_size)

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.compat.v1.variable_scope(name):
            self.X = tf.compat.v1.placeholder(tf.float32, (None, None, input_size))
            self.Y = tf.compat.v1.placeholder(tf.float32, (None, output_size))
            self.hidden_layer = tf.compat.v1.placeholder(tf.float32, (None, 2 * size_layer))
            self.REWARD = tf.compat.v1.placeholder(tf.float32, (None, 1))
            feed_critic = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            cell = tf.compat.v1.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)
            self.rnn,self.last_state = tf.compat.v1.nn.dynamic_rnn(inputs=self.X, cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            feed_critic = tf.compat.v1.layers.dense(self.rnn[:,-1], output_size, activation = tf.nn.relu) + self.Y
            feed_critic = tf.compat.v1.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.compat.v1.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(input_tensor=tf.square(self.REWARD - self.logits))
            self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate).minimize(self.cost)

class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE,
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(ys=self.critic.logits, xs=self.critic.Y)
        self.actor_critic_grad = tf.compat.v1.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(ys=self.actor.logits, xs=weights_actor, grad_ys=-self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.compat.v1.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())

    def _assign(self, from_name, to_name):
        from_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action

    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states,
                                                       self.actor.hidden_layer: init_values})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states,
                                                                     self.actor_target.hidden_layer: init_values})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q,
                                                          self.critic.hidden_layer: init_values})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads,
                                                self.actor.hidden_layer: init_values})

        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits,
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target,
                                                 self.critic_target.hidden_layer: init_values})
        for i in range(len(replay)):
            if not replay[0][-2]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer],
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards,
                                          self.critic.hidden_layer: init_values})
        return cost

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)

    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):

            if np.random.rand() < self.EPSILON:
                action = np.random.randint(self.OUTPUT_SIZE)
            else:
                action, last_state = self.sess.run([self.actor.logits,
                                                  self.actor.last_state],
                                                  feed_dict={self.actor.X:[self.INITIAL_FEATURES],
                                                             self.actor.hidden_layer:init_value})
                action, init_value = np.argmax(action[0]), last_state

            next_state = self.get_state(t + 1)

            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )

            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')

                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.actor.logits,
                                                  self.actor.last_state],
                                                  feed_dict={self.actor.X:[self.INITIAL_FEATURES],
                                                             self.actor.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state

                next_state = self.get_state(t + 1)

                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]

                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state,
                               starting_money < initial_money, init_value[0])
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                self.INITIAL_FEATURES = new_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
tf.compat.v1.disable_eager_execution()

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size,
              window_size = window_size,
              trend = close,
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# <ipython-input-4-0c6d67aefb67>:9: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)
# WARNING:tensorflow:<keras.layers.rnn.legacy_cells.LSTMCell object at 0x7f97978705e0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:From <ipython-input-4-0c6d67aefb67>:10: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:958: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# <ipython-input-4-0c6d67aefb67>:13: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(self.rnn[:,-1], output_size)
# WARNING:tensorflow:<keras.layers.rnn.legacy_cells.LSTMCell object at 0x7f9797861520>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# <ipython-input-4-0c6d67aefb67>:22: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
# <ipython-input-4-0c6d67aefb67>:23: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)
# WARNING:tensorflow:<keras.layers.rnn.legacy_cells.LSTMCell object at 0x7f9797853cd0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# <ipython-input-4-0c6d67aefb67>:27: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(self.rnn[:,-1], output_size, activation = tf.nn.relu) + self.Y
# <ipython-input-4-0c6d67aefb67>:28: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
# <ipython-input-4-0c6d67aefb67>:29: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(feed_critic, 1)
# WARNING:tensorflow:<keras.layers.rnn.legacy_cells.LSTMCell object at 0x7f9797861af0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# epoch: 10, total rewards: -16.360005.3, cost: 0.000604, total money: 9938.929995
# epoch: 20, total rewards: -26.200000.3, cost: 0.000015, total money: 9961.600000
# epoch: 30, total rewards: -19.649997.3, cost: 0.000046, total money: 9956.980003
# epoch: 40, total rewards: -7.359998.3, cost: 0.000070, total money: 9968.870002
# epoch: 50, total rewards: -1.800007.3, cost: 0.000344, total money: 9986.399993
# epoch: 60, total rewards: -121.480008.3, cost: 0.000280, total money: 9589.189992
# epoch: 70, total rewards: -19.709998.3, cost: 0.000020, total money: 9980.290002
# epoch: 80, total rewards: -3.230007.3, cost: 0.001880, total money: 9996.769993
# epoch: 90, total rewards: -70.220004.3, cost: 0.009765, total money: 9873.969996
# epoch: 100, total rewards: -151.690002.3, cost: 0.008621, total money: 8200.119995
# epoch: 110, total rewards: -39.900002.3, cost: 0.000208, total money: 9915.139998
# epoch: 120, total rewards: -32.059999.3, cost: 0.010096, total money: 9745.270001
# epoch: 130, total rewards: -58.220009.3, cost: 0.000139, total money: 9941.779991
# epoch: 140, total rewards: -30.030001.3, cost: 0.000073, total money: 9866.209999
# epoch: 150, total rewards: -9.950002.3, cost: 0.026984, total money: 9977.849998
# epoch: 160, total rewards: -6.280005.3, cost: 0.000002, total money: 9993.719995
# epoch: 170, total rewards: -2.659993.3, cost: 0.000015, total money: 9997.340007
# epoch: 180, total rewards: -100.260001.3, cost: 0.002134, total money: 9647.449999
# epoch: 190, total rewards: 1.569999.3, cost: 0.000453, total money: 10001.569999
# epoch: 200, total rewards: -1.549997.3, cost: 0.000437, total money: 9998.450003

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 20.799999, total balance 9979.200001
# day 2, sell 1 unit at price 20.370001, investment -2.067298 %, total balance 9999.570002,
# day 4: buy 1 unit at price 20.510000, total balance 9979.060002
# day 5, sell 1 unit at price 20.700001, investment 0.926382 %, total balance 9999.760003,
# day 12: buy 1 unit at price 20.770000, total balance 9978.990003
# day 15, sell 1 unit at price 20.990000, investment 1.059220 %, total balance 9999.980003,
# day 21: buy 1 unit at price 21.240000, total balance 9978.740003
# day 22, sell 1 unit at price 21.270000, investment 0.141243 %, total balance 10000.010003,
# day 27: buy 1 unit at price 21.200001, total balance 9978.810002
# day 28, sell 1 unit at price 21.059999, investment -0.660387 %, total balance 9999.870001,
# day 29: buy 1 unit at price 21.090000, total balance 9978.780001
# day 30: buy 1 unit at price 20.730000, total balance 9958.050001
# day 31: buy 1 unit at price 20.740000, total balance 9937.310001
# day 32, sell 1 unit at price 19.680000, investment -6.685633 %, total balance 9956.990001,
# day 33, sell 1 unit at price 19.750000, investment -4.727448 %, total balance 9976.740001,
# day 34: buy 1 unit at price 19.910000, total balance 9956.830001
# day 35, sell 1 unit at price 19.840000, investment -4.339441 %, total balance 9976.670001,
# day 37: buy 1 unit at price 19.480000, total balance 9957.190001
# day 39, sell 1 unit at price 19.370001, investment -2.712200 %, total balance 9976.560002,
# day 40: buy 1 unit at price 19.600000, total balance 9956.960002
# day 41: buy 1 unit at price 19.770000, total balance 9937.190002
# day 42, sell 1 unit at price 19.830000, investment 1.796715 %, total balance 9957.020002,
# day 43, sell 1 unit at price 19.889999, investment 1.479587 %, total balance 9976.910001,
# day 44, sell 1 unit at price 19.760000, investment -0.050582 %, total balance 9996.670001,
# day 61: buy 1 unit at price 19.430000, total balance 9977.240001
# day 63, sell 1 unit at price 19.740000, investment 1.595471 %, total balance 9996.980001,
# day 71: buy 1 unit at price 18.400000, total balance 9978.580001
# day 72, sell 1 unit at price 18.760000, investment 1.956522 %, total balance 9997.340001,
# day 79: buy 1 unit at price 19.150000, total balance 9978.190001
# day 80, sell 1 unit at price 18.920000, investment -1.201044 %, total balance 9997.110001,
# day 82: buy 1 unit at price 19.000000, total balance 9978.110001
# day 83, sell 1 unit at price 18.870001, investment -0.684205 %, total balance 9996.980002,
# day 87: buy 1 unit at price 19.059999, total balance 9977.920003
# day 88, sell 1 unit at price 18.990000, investment -0.367256 %, total balance 9996.910003,
# day 95: buy 1 unit at price 17.700001, total balance 9979.210002
# day 96, sell 1 unit at price 17.510000, investment -1.073452 %, total balance 9996.720002,
# day 97: buy 1 unit at price 17.360001, total balance 9979.360001
# day 98, sell 1 unit at price 17.260000, investment -0.576043 %, total balance 9996.620001,
# day 99: buy 1 unit at price 16.600000, total balance 9980.020001
# day 100, sell 1 unit at price 16.719999, investment 0.722886 %, total balance 9996.740000,
# day 106: buy 1 unit at price 17.059999, total balance 9979.680001
# day 107, sell 1 unit at price 16.860001, investment -1.172321 %, total balance 9996.540002,
# day 108: buy 1 unit at price 16.620001, total balance 9979.920001
# day 109, sell 1 unit at price 15.740000, investment -5.294831 %, total balance 9995.660001,
# day 116: buy 1 unit at price 15.420000, total balance 9980.240001
# day 117, sell 1 unit at price 15.600000, investment 1.167315 %, total balance 9995.840001,
# day 120: buy 1 unit at price 15.400000, total balance 9980.440001
# day 121, sell 1 unit at price 15.710000, investment 2.012987 %, total balance 9996.150001,
# day 126: buy 1 unit at price 16.020000, total balance 9980.130001
# day 127, sell 1 unit at price 15.810000, investment -1.310861 %, total balance 9995.940001,
# day 128: buy 1 unit at price 15.800000, total balance 9980.140001
# day 129, sell 1 unit at price 15.900000, investment 0.632911 %, total balance 9996.040001,
# day 131: buy 1 unit at price 15.930000, total balance 9980.110001
# day 132, sell 1 unit at price 15.650000, investment -1.757690 %, total balance 9995.760001,
# day 136: buy 1 unit at price 14.890000, total balance 9980.870001
# day 137, sell 1 unit at price 14.820000, investment -0.470114 %, total balance 9995.690001,
# day 149: buy 1 unit at price 14.160000, total balance 9981.530001
# day 151, sell 1 unit at price 14.180000, investment 0.141243 %, total balance 9995.710001,
# day 161: buy 1 unit at price 14.570000, total balance 9981.140001
# day 162: buy 1 unit at price 14.340000, total balance 9966.800001
# day 164, sell 1 unit at price 14.800000, investment 1.578586 %, total balance 9981.600001,
# day 165: buy 1 unit at price 14.730000, total balance 9966.870001
# day 166, sell 1 unit at price 15.030000, investment 4.811715 %, total balance 9981.900001,
# day 169, sell 1 unit at price 15.260000, investment 3.598099 %, total balance 9997.160001,
# day 170: buy 1 unit at price 15.290000, total balance 9981.870001
# day 171, sell 1 unit at price 15.360000, investment 0.457816 %, total balance 9997.230001,
# day 181: buy 1 unit at price 15.280000, total balance 9981.950001
# day 183, sell 1 unit at price 15.600000, investment 2.094241 %, total balance 9997.550001,
# day 184: buy 1 unit at price 15.780000, total balance 9981.770001
# day 185: buy 1 unit at price 15.340000, total balance 9966.430001
# day 186: buy 1 unit at price 15.240000, total balance 9951.190001
# day 187: buy 1 unit at price 15.170000, total balance 9936.020001
# day 188: buy 1 unit at price 15.330000, total balance 9920.690001
# day 189: buy 1 unit at price 15.240000, total balance 9905.450001
# day 190: buy 1 unit at price 15.170000, total balance 9890.280001
# day 191: buy 1 unit at price 15.050000, total balance 9875.230001
# day 192: buy 1 unit at price 14.880000, total balance 9860.350001
# day 194: buy 1 unit at price 15.050000, total balance 9845.300001
# day 195: buy 1 unit at price 15.150000, total balance 9830.150001
# day 196: buy 1 unit at price 14.660000, total balance 9815.490001
# day 197: buy 1 unit at price 14.780000, total balance 9800.710001
# day 199: buy 1 unit at price 14.510000, total balance 9786.200001
# day 200: buy 1 unit at price 14.370000, total balance 9771.830001
# day 201: buy 1 unit at price 14.400000, total balance 9757.430001
# day 203: buy 1 unit at price 14.200000, total balance 9743.230001
# day 204: buy 1 unit at price 14.050000, total balance 9729.180001
# day 205, sell 1 unit at price 13.590000, investment -13.878327 %, total balance 9742.770001,
# day 206, sell 1 unit at price 13.550000, investment -11.668840 %, total balance 9756.320001,
# day 207: buy 1 unit at price 13.500000, total balance 9742.820001
# day 208, sell 1 unit at price 13.080000, investment -14.173228 %, total balance 9755.900001,
# day 209, sell 1 unit at price 13.300000, investment -12.326961 %, total balance 9769.200001,
# day 210, sell 1 unit at price 12.860000, investment -16.112198 %, total balance 9782.060001,
# day 211, sell 1 unit at price 12.860000, investment -15.616798 %, total balance 9794.920001,
# day 212, sell 1 unit at price 13.020000, investment -14.172709 %, total balance 9807.940001,
# day 213, sell 1 unit at price 12.670000, investment -15.813953 %, total balance 9820.610001,
# day 214, sell 1 unit at price 12.410000, investment -16.599462 %, total balance 9833.020001,
# day 215: buy 1 unit at price 12.420000, total balance 9820.600001
# day 216, sell 1 unit at price 12.030000, investment -20.066445 %, total balance 9832.630001,
# day 217: buy 1 unit at price 12.330000, total balance 9820.300001
# day 218: buy 1 unit at price 12.520000, total balance 9807.780001
# day 219, sell 1 unit at price 12.280000, investment -18.943894 %, total balance 9820.060001,
# day 220, sell 1 unit at price 12.330000, investment -15.893588 %, total balance 9832.390001,
# day 221, sell 1 unit at price 12.410000, investment -16.035183 %, total balance 9844.800001,
# day 222, sell 1 unit at price 12.220000, investment -15.782219 %, total balance 9857.020001,
# day 223: buy 1 unit at price 12.130000, total balance 9844.890001
# day 224, sell 1 unit at price 11.870000, investment -17.397356 %, total balance 9856.760001,
# day 225: buy 1 unit at price 11.360000, total balance 9845.400001
# day 226, sell 1 unit at price 11.350000, investment -21.180556 %, total balance 9856.750001,
# day 227, sell 1 unit at price 11.470000, investment -19.225352 %, total balance 9868.220001,
# day 228, sell 1 unit at price 11.770000, investment -16.227758 %, total balance 9879.990001,
# day 229, sell 1 unit at price 11.750000, investment -12.962963 %, total balance 9891.740001,
# day 231, sell 1 unit at price 11.540000, investment -7.085346 %, total balance 9903.280001,
# day 232, sell 1 unit at price 11.480000, investment -6.893755 %, total balance 9914.760001,
# day 233: buy 1 unit at price 11.370000, total balance 9903.390001
# day 234, sell 1 unit at price 11.340000, investment -9.424920 %, total balance 9914.730001,
# day 235, sell 1 unit at price 11.050000, investment -8.903545 %, total balance 9925.780001,
# day 236, sell 1 unit at price 11.250000, investment -0.968310 %, total balance 9937.030001,
# day 237, sell 1 unit at price 11.010000, investment -3.166227 %, total balance 9948.040001,
# day 244: buy 1 unit at price 11.380000, total balance 9936.660001
# day 245, sell 1 unit at price 11.170000, investment -1.845343 %, total balance 9947.830001,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
