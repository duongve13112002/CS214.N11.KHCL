# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('/content/drive/MyDrive/Đồ án biểu diễn (Dự báo giá chứng khoán)/dataset/VNM.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2021-12-01  20.879999  20.980000  20.750000  20.799999  20.696852  195600
# 1  2021-12-02  20.799999  20.850000  20.680000  20.719999  20.617249  296800
# 2  2021-12-03  20.500000  20.549999  20.280001  20.370001  20.268986  251000
# 3  2021-12-06  20.000000  20.049999  19.870001  20.010000  19.910770  502800
# 4  2021-12-07  20.379999  20.559999  20.320000  20.510000  20.408291  339700

# %%
class Agent:

    LEARNING_RATE = 1e-4
    LAYER_SIZE = 256
    GAMMA = 0.9
    OUTPUT_SIZE = 3

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.X = tf.compat.v1.placeholder(tf.float32, (None, self.state_size))
        self.REWARDS = tf.compat.v1.placeholder(tf.float32, (None))
        self.ACTIONS = tf.compat.v1.placeholder(tf.int32, (None))
        feed_forward = tf.compat.v1.layers.dense(self.X, self.LAYER_SIZE, activation = tf.nn.relu)
        self.logits = tf.compat.v1.layers.dense(feed_forward, self.OUTPUT_SIZE, activation = tf.nn.softmax)
        input_y = tf.one_hot(self.ACTIONS, self.OUTPUT_SIZE)
        loglike = tf.math.log((input_y * (input_y - self.logits) + (1 - input_y) * (input_y + self.logits)) + 1)
        rewards = tf.tile(tf.reshape(self.REWARDS, (-1,1)), [1, self.OUTPUT_SIZE])
        self.cost = -tf.reduce_mean(loglike * (rewards + 1)) 
        self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def discount_rewards(self, r):
        discounted_r = np.zeros_like(r)
        running_add = 0
        for t in reversed(range(0, r.size)):
            running_add = running_add * self.GAMMA + r[t]
            discounted_r[t] = running_add
        return discounted_r
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.get_predicted_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            ep_history = []
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.get_predicted_action(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= close[t]
                
                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                ep_history.append([state,action,starting_money,next_state])
                state = next_state
            ep_history = np.array(ep_history)
            ep_history[:,2] = self.discount_rewards(ep_history[:,2])
            cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict={self.X:np.vstack(ep_history[:,0]),
                                                    self.REWARDS:ep_history[:,2],
                                                    self.ACTIONS:ep_history[:,1]})
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
tf.compat.v1.disable_eager_execution()

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
agent = Agent(state_size = window_size,
             window_size = window_size,
             trend = close,
             skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# <ipython-input-23-bbb99d10b8c6>:17: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_forward = tf.compat.v1.layers.dense(self.X, self.LAYER_SIZE, activation = tf.nn.relu)
# <ipython-input-23-bbb99d10b8c6>:18: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(feed_forward, self.OUTPUT_SIZE, activation = tf.nn.softmax)
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/client/session.py:1768: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# <ipython-input-23-bbb99d10b8c6>:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ep_history = np.array(ep_history)
# epoch: 10, total rewards: -25.799999.3, cost: -33776.601562, total money: 9974.200001
# epoch: 20, total rewards: -54.580002.3, cost: -33698.375000, total money: 9897.829998
# epoch: 30, total rewards: -56.450002.3, cost: -33846.933594, total money: 9895.959998
# epoch: 40, total rewards: -47.280009.3, cost: -33983.519531, total money: 9868.819991
# epoch: 50, total rewards: -47.300005.3, cost: -34058.476562, total money: 9893.619995
# epoch: 60, total rewards: -63.870009.3, cost: -34072.378906, total money: 9864.379991
# epoch: 70, total rewards: -52.490010.3, cost: -34167.312500, total money: 9936.139990
# epoch: 80, total rewards: -54.579997.3, cost: -34139.796875, total money: 9945.420003
# epoch: 90, total rewards: -73.649998.3, cost: -34089.593750, total money: 9926.350002
# epoch: 100, total rewards: -108.149991.3, cost: -33726.570312, total money: 9748.380009
# epoch: 110, total rewards: -118.019996.3, cost: -33668.800781, total money: 9709.200004
# epoch: 120, total rewards: -64.309999.3, cost: -34222.320312, total money: 9935.690001
# epoch: 130, total rewards: -34.440003.3, cost: -34489.871094, total money: 9965.559997
# epoch: 140, total rewards: -101.779990.3, cost: -33551.925781, total money: 9425.170010
# epoch: 150, total rewards: -72.130000.3, cost: -34257.308594, total money: 9771.850000
# epoch: 160, total rewards: -34.629998.3, cost: -34573.238281, total money: 9965.370002
# epoch: 170, total rewards: -50.359991.3, cost: -34499.261719, total money: 9926.930009
# epoch: 180, total rewards: -93.989993.3, cost: -33216.332031, total money: 9173.000006
# epoch: 190, total rewards: -16.339990.3, cost: -34706.949219, total money: 9983.660010
# epoch: 200, total rewards: -176.449995.3, cost: -32698.029297, total money: 9052.200005

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 2: buy 1 unit at price 20.370001, total balance 9979.629999
# day 3, sell 1 unit at price 20.010000, investment -1.767310 %, total balance 9999.639999,
# day 6: buy 1 unit at price 20.850000, total balance 9978.789999
# day 7: buy 1 unit at price 20.680000, total balance 9958.109999
# day 8, sell 1 unit at price 20.680000, investment -0.815348 %, total balance 9978.789999,
# day 10: buy 1 unit at price 20.740000, total balance 9958.049999
# day 12: buy 1 unit at price 20.770000, total balance 9937.279999
# day 13, sell 1 unit at price 20.600000, investment -0.386847 %, total balance 9957.879999,
# day 19, sell 1 unit at price 21.010000, investment 1.301832 %, total balance 9978.889999,
# day 22: buy 1 unit at price 21.270000, total balance 9957.619999
# day 24: buy 1 unit at price 21.490000, total balance 9936.129999
# day 27: buy 1 unit at price 21.200001, total balance 9914.929998
# day 28, sell 1 unit at price 21.059999, investment 1.396240 %, total balance 9935.989997,
# day 31, sell 1 unit at price 20.740000, investment -2.491772 %, total balance 9956.729997,
# day 32: buy 1 unit at price 19.680000, total balance 9937.049997
# day 33, sell 1 unit at price 19.750000, investment -8.096789 %, total balance 9956.799997,
# day 34: buy 1 unit at price 19.910000, total balance 9936.889997
# day 35: buy 1 unit at price 19.840000, total balance 9917.049997
# day 39, sell 1 unit at price 19.370001, investment -8.632075 %, total balance 9936.419998,
# day 41: buy 1 unit at price 19.770000, total balance 9916.649998
# day 42, sell 1 unit at price 19.830000, investment 0.762195 %, total balance 9936.479998,
# day 44, sell 1 unit at price 19.760000, investment -0.753390 %, total balance 9956.239998,
# day 46, sell 1 unit at price 19.740000, investment -0.504032 %, total balance 9975.979998,
# day 47: buy 1 unit at price 19.650000, total balance 9956.329998
# day 48, sell 1 unit at price 20.030001, investment 1.315129 %, total balance 9976.359999,
# day 51: buy 1 unit at price 19.400000, total balance 9956.959999
# day 52, sell 1 unit at price 19.650000, investment 0.000000 %, total balance 9976.609999,
# day 53: buy 1 unit at price 19.809999, total balance 9956.800000
# day 61: buy 1 unit at price 19.430000, total balance 9937.370000
# day 64, sell 1 unit at price 19.639999, investment 1.237108 %, total balance 9957.009999,
# day 65: buy 1 unit at price 19.240000, total balance 9937.769999
# day 66: buy 1 unit at price 18.969999, total balance 9918.800000
# day 69, sell 1 unit at price 18.530001, investment -6.461373 %, total balance 9937.330001,
# day 72, sell 1 unit at price 18.760000, investment -3.448276 %, total balance 9956.090001,
# day 74: buy 1 unit at price 18.850000, total balance 9937.240001
# day 75: buy 1 unit at price 19.190001, total balance 9918.050000
# day 77, sell 1 unit at price 19.219999, investment -0.103955 %, total balance 9937.269999,
# day 79, sell 1 unit at price 19.150000, investment 0.948872 %, total balance 9956.419999,
# day 83, sell 1 unit at price 18.870001, investment 0.106106 %, total balance 9975.290000,
# day 85: buy 1 unit at price 19.450001, total balance 9955.839999
# day 91: buy 1 unit at price 18.559999, total balance 9937.280000
# day 92: buy 1 unit at price 18.750000, total balance 9918.530000
# day 93: buy 1 unit at price 18.540001, total balance 9899.989999
# day 97, sell 1 unit at price 17.360001, investment -9.536216 %, total balance 9917.350000,
# day 99: buy 1 unit at price 16.600000, total balance 9900.750000
# day 100: buy 1 unit at price 16.719999, total balance 9884.030001
# day 101, sell 1 unit at price 16.959999, investment -12.802066 %, total balance 9900.990000,
# day 105: buy 1 unit at price 17.219999, total balance 9883.770001
# day 106, sell 1 unit at price 17.059999, investment -8.081897 %, total balance 9900.830000,
# day 110, sell 1 unit at price 16.139999, investment -13.920005 %, total balance 9916.969999,
# day 113: buy 1 unit at price 15.230000, total balance 9901.739999
# day 115, sell 1 unit at price 15.650000, investment -15.587923 %, total balance 9917.389999,
# day 119, sell 1 unit at price 15.310000, investment -7.771084 %, total balance 9932.699999,
# day 121: buy 1 unit at price 15.710000, total balance 9916.989999
# day 123, sell 1 unit at price 15.900000, investment -4.904301 %, total balance 9932.889999,
# day 126, sell 1 unit at price 16.020000, investment -6.968636 %, total balance 9948.909999,
# day 128, sell 1 unit at price 15.800000, investment 3.742613 %, total balance 9964.709999,
# day 129, sell 1 unit at price 15.900000, investment 1.209421 %, total balance 9980.609999,
# day 131: buy 1 unit at price 15.930000, total balance 9964.679999
# day 133: buy 1 unit at price 14.950000, total balance 9949.729999
# day 134: buy 1 unit at price 15.050000, total balance 9934.679999
# day 135: buy 1 unit at price 14.980000, total balance 9919.699999
# day 138: buy 1 unit at price 14.540000, total balance 9905.159999
# day 140, sell 1 unit at price 14.650000, investment -8.035154 %, total balance 9919.809999,
# day 145: buy 1 unit at price 14.400000, total balance 9905.409999
# day 146, sell 1 unit at price 14.480000, investment -3.143813 %, total balance 9919.889999,
# day 147, sell 1 unit at price 14.090000, investment -6.378738 %, total balance 9933.979999,
# day 148, sell 1 unit at price 13.800000, investment -7.877170 %, total balance 9947.779999,
# day 154, sell 1 unit at price 14.340000, investment -1.375516 %, total balance 9962.119999,
# day 156, sell 1 unit at price 14.270000, investment -0.902778 %, total balance 9976.389999,
# day 168: buy 1 unit at price 15.220000, total balance 9961.169999
# day 169, sell 1 unit at price 15.260000, investment 0.262812 %, total balance 9976.429999,
# day 179: buy 1 unit at price 15.640000, total balance 9960.789999
# day 180, sell 1 unit at price 15.450000, investment -1.214834 %, total balance 9976.239999,
# day 182: buy 1 unit at price 15.470000, total balance 9960.769999
# day 183, sell 1 unit at price 15.600000, investment 0.840336 %, total balance 9976.369999,
# day 192: buy 1 unit at price 14.880000, total balance 9961.489999
# day 193: buy 1 unit at price 14.860000, total balance 9946.629999
# day 194: buy 1 unit at price 15.050000, total balance 9931.579999
# day 195: buy 1 unit at price 15.150000, total balance 9916.429999
# day 196: buy 1 unit at price 14.660000, total balance 9901.769999
# day 198: buy 1 unit at price 14.650000, total balance 9887.119999
# day 199, sell 1 unit at price 14.510000, investment -2.486559 %, total balance 9901.629999,
# day 200: buy 1 unit at price 14.370000, total balance 9887.259999
# day 201: buy 1 unit at price 14.400000, total balance 9872.859999
# day 202: buy 1 unit at price 14.350000, total balance 9858.509999
# day 203: buy 1 unit at price 14.200000, total balance 9844.309999
# day 204: buy 1 unit at price 14.050000, total balance 9830.259999
# day 205, sell 1 unit at price 13.590000, investment -8.546433 %, total balance 9843.849999,
# day 206, sell 1 unit at price 13.550000, investment -9.966777 %, total balance 9857.399999,
# day 208, sell 1 unit at price 13.080000, investment -13.663366 %, total balance 9870.479999,
# day 209, sell 1 unit at price 13.300000, investment -9.276944 %, total balance 9883.779999,
# day 211: buy 1 unit at price 12.860000, total balance 9870.919999
# day 214, sell 1 unit at price 12.410000, investment -15.290102 %, total balance 9883.329999,
# day 215: buy 1 unit at price 12.420000, total balance 9870.909999
# day 220: buy 1 unit at price 12.330000, total balance 9858.579999
# day 221, sell 1 unit at price 12.410000, investment -13.639527 %, total balance 9870.989999,
# day 226, sell 1 unit at price 11.350000, investment -21.180556 %, total balance 9882.339999,
# day 240, sell 1 unit at price 10.940000, investment -23.763066 %, total balance 9893.279999,
# day 241, sell 1 unit at price 10.900000, investment -23.239437 %, total balance 9904.179999,
# day 242, sell 1 unit at price 11.260000, investment -19.857651 %, total balance 9915.439999,
# day 249, sell 1 unit at price 11.800000, investment -8.242613 %, total balance 9927.239999,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
