# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('/content/drive/MyDrive/Đồ án biểu diễn (Dự báo giá chứng khoán)/dataset/VNM.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2021-12-01  20.879999  20.980000  20.750000  20.799999  20.696852  195600
# 1  2021-12-02  20.799999  20.850000  20.680000  20.719999  20.617249  296800
# 2  2021-12-03  20.500000  20.549999  20.280001  20.370001  20.268986  251000
# 3  2021-12-06  20.000000  20.049999  19.870001  20.010000  19.910770  502800
# 4  2021-12-07  20.379999  20.559999  20.320000  20.510000  20.408291  339700

# %%
from collections import deque
import random

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.compat.v1.variable_scope(name):
            self.X = tf.compat.v1.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            tensor_action, tensor_validation = tf.split(feed_actor,2,1)
            feed_action = tf.compat.v1.layers.dense(tensor_action, output_size)
            feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,
                                                        tf.reduce_mean(input_tensor=feed_action,axis=1,keepdims=True))

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.compat.v1.variable_scope(name):
            self.X = tf.compat.v1.placeholder(tf.float32, (None, input_size))
            self.Y = tf.compat.v1.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.compat.v1.placeholder(tf.float32, (None, 1))
            feed_critic = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            tensor_action, tensor_validation = tf.split(feed_critic,2,1)
            feed_action = tf.compat.v1.layers.dense(tensor_action, output_size)
            feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
            feed_critic = feed_validation + tf.subtract(feed_action,tf.reduce_mean(input_tensor=feed_action,axis=1,keepdims=True))
            feed_critic = tf.nn.relu(feed_critic) + self.Y
            feed_critic = tf.compat.v1.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.compat.v1.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(input_tensor=tf.square(self.REWARD - self.logits))
            self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate).minimize(self.cost)

class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE,
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(ys=self.critic.logits, xs=self.critic.Y)
        self.actor_critic_grad = tf.compat.v1.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(ys=self.actor.logits, xs=weights_actor, grad_ys=-self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.compat.v1.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())

    def _assign(self, from_name, to_name):
        from_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action

    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})

        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits,
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer],
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)

    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)

            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )

            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')

                action = self._select_action(state)
                next_state = self.get_state(t + 1)

                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]

                invest = ((starting_money - initial_money) / initial_money)

                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
tf.compat.v1.disable_eager_execution()

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size,
              window_size = window_size,
              trend = close,
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# <ipython-input-4-5677740f4777>:8: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_actor = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
# <ipython-input-4-5677740f4777>:10: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_action = tf.compat.v1.layers.dense(tensor_action, output_size)
# <ipython-input-4-5677740f4777>:11: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
# <ipython-input-4-5677740f4777>:21: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
# <ipython-input-4-5677740f4777>:23: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_action = tf.compat.v1.layers.dense(tensor_action, output_size)
# <ipython-input-4-5677740f4777>:24: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
# <ipython-input-4-5677740f4777>:27: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
# <ipython-input-4-5677740f4777>:28: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(feed_critic, 1)
# epoch: 10, total rewards: -116.190016.3, cost: 0.000323, total money: 9435.389984
# epoch: 20, total rewards: -123.099994.3, cost: 0.000124, total money: 9796.110006
# epoch: 30, total rewards: -17.549996.3, cost: 0.000788, total money: 9982.450004
# epoch: 40, total rewards: -11.519991.3, cost: 0.000012, total money: 9988.480009
# epoch: 50, total rewards: -32.009997.3, cost: 0.001087, total money: 9955.790003
# epoch: 60, total rewards: -11.040004.3, cost: 0.000346, total money: 9932.779996
# epoch: 70, total rewards: -161.569995.3, cost: 0.000867, total money: 9105.660005
# epoch: 80, total rewards: -46.940010.3, cost: 0.002920, total money: 9595.389990
# epoch: 90, total rewards: -17.540005.3, cost: 0.000406, total money: 9982.459995
# epoch: 100, total rewards: -180.320002.3, cost: 0.007206, total money: 9714.449998
# epoch: 110, total rewards: -233.380005.3, cost: 0.001579, total money: 8480.239996
# epoch: 120, total rewards: -184.669999.3, cost: 0.002975, total money: 8377.520000
# epoch: 130, total rewards: -204.680008.3, cost: 0.001071, total money: 8799.219992
# epoch: 140, total rewards: -116.009997.3, cost: 0.001650, total money: 8717.910003
# epoch: 150, total rewards: -184.820001.3, cost: 0.002520, total money: 8568.039999
# epoch: 160, total rewards: -213.279998.3, cost: 0.002590, total money: 8122.110000
# epoch: 170, total rewards: -146.980003.3, cost: 0.002676, total money: 7949.589995
# epoch: 180, total rewards: -156.020002.3, cost: 0.007136, total money: 7863.919992
# epoch: 190, total rewards: -203.299999.3, cost: 0.004883, total money: 8196.809998
# epoch: 200, total rewards: -219.350005.3, cost: 0.002657, total money: 8314.029989

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 2: buy 1 unit at price 20.370001, total balance 9979.629999
# day 3, sell 1 unit at price 20.010000, investment -1.767310 %, total balance 9999.639999,
# day 4: buy 1 unit at price 20.510000, total balance 9979.129999
# day 5: buy 1 unit at price 20.700001, total balance 9958.429998
# day 6: buy 1 unit at price 20.850000, total balance 9937.579998
# day 7, sell 1 unit at price 20.680000, investment 0.828864 %, total balance 9958.259998,
# day 8: buy 1 unit at price 20.680000, total balance 9937.579998
# day 9, sell 1 unit at price 20.690001, investment -0.048309 %, total balance 9958.269999,
# day 10: buy 1 unit at price 20.740000, total balance 9937.529999
# day 11: buy 1 unit at price 20.709999, total balance 9916.820000
# day 12: buy 1 unit at price 20.770000, total balance 9896.050000
# day 13, sell 1 unit at price 20.600000, investment -1.199041 %, total balance 9916.650000,
# day 15: buy 1 unit at price 20.990000, total balance 9895.660000
# day 16: buy 1 unit at price 20.660000, total balance 9875.000000
# day 17: buy 1 unit at price 21.010000, total balance 9853.990000
# day 18: buy 1 unit at price 21.049999, total balance 9832.940001
# day 20, sell 1 unit at price 21.260000, investment 2.804642 %, total balance 9854.200001,
# day 21: buy 1 unit at price 21.240000, total balance 9832.960001
# day 22: buy 1 unit at price 21.270000, total balance 9811.690001
# day 23, sell 1 unit at price 21.530001, investment 3.809069 %, total balance 9833.220002,
# day 25: buy 1 unit at price 21.389999, total balance 9811.830003
# day 26, sell 1 unit at price 21.400000, investment 3.331729 %, total balance 9833.230003,
# day 27: buy 1 unit at price 21.200001, total balance 9812.030002
# day 28: buy 1 unit at price 21.059999, total balance 9790.970003
# day 29: buy 1 unit at price 21.090000, total balance 9769.880003
# day 30: buy 1 unit at price 20.730000, total balance 9749.150003
# day 31: buy 1 unit at price 20.740000, total balance 9728.410003
# day 34: buy 1 unit at price 19.910000, total balance 9708.500003
# day 35: buy 1 unit at price 19.840000, total balance 9688.660003
# day 36, sell 1 unit at price 19.120001, investment -7.944145 %, total balance 9707.780004,
# day 38: buy 1 unit at price 19.330000, total balance 9688.450004
# day 39: buy 1 unit at price 19.370001, total balance 9669.080003
# day 42: buy 1 unit at price 19.830000, total balance 9649.250003
# day 43: buy 1 unit at price 19.889999, total balance 9629.360004
# day 44: buy 1 unit at price 19.760000, total balance 9609.600004
# day 45: buy 1 unit at price 19.719999, total balance 9589.880005
# day 46, sell 1 unit at price 19.740000, investment -5.955217 %, total balance 9609.620005,
# day 47: buy 1 unit at price 19.650000, total balance 9589.970005
# day 48: buy 1 unit at price 20.030001, total balance 9569.940004
# day 49: buy 1 unit at price 19.870001, total balance 9550.070003
# day 50: buy 1 unit at price 19.620001, total balance 9530.450002
# day 51: buy 1 unit at price 19.400000, total balance 9511.050002
# day 52: buy 1 unit at price 19.650000, total balance 9491.400002
# day 53, sell 1 unit at price 19.809999, investment -4.114235 %, total balance 9511.210001,
# day 56: buy 1 unit at price 19.639999, total balance 9491.570002
# day 57: buy 1 unit at price 19.680000, total balance 9471.890002
# day 58, sell 1 unit at price 19.500000, investment -7.187054 %, total balance 9491.390002,
# day 60: buy 1 unit at price 19.510000, total balance 9471.880002
# day 61, sell 1 unit at price 19.430000, investment -7.695958 %, total balance 9491.310002,
# day 62: buy 1 unit at price 19.549999, total balance 9471.760003
# day 63: buy 1 unit at price 19.740000, total balance 9452.020003
# day 64, sell 1 unit at price 19.639999, investment -7.532961 %, total balance 9471.660002,
# day 65: buy 1 unit at price 19.240000, total balance 9452.420002
# day 66: buy 1 unit at price 18.969999, total balance 9433.450003
# day 67: buy 1 unit at price 19.120001, total balance 9414.330002
# day 68: buy 1 unit at price 18.969999, total balance 9395.360003
# day 70: buy 1 unit at price 18.200001, total balance 9377.160002
# day 71: buy 1 unit at price 18.400000, total balance 9358.760002
# day 73: buy 1 unit at price 18.620001, total balance 9340.140001
# day 75, sell 1 unit at price 19.190001, investment -9.779027 %, total balance 9359.330002,
# day 76, sell 1 unit at price 19.270000, investment -9.911169 %, total balance 9378.600002,
# day 77: buy 1 unit at price 19.219999, total balance 9359.380003
# day 79, sell 1 unit at price 19.150000, investment -9.669816 %, total balance 9378.530003,
# day 80: buy 1 unit at price 18.920000, total balance 9359.610003
# day 81: buy 1 unit at price 19.110001, total balance 9340.500002
# day 82: buy 1 unit at price 19.000000, total balance 9321.500002
# day 83: buy 1 unit at price 18.870001, total balance 9302.630001
# day 84: buy 1 unit at price 19.190001, total balance 9283.440000
# day 85: buy 1 unit at price 19.450001, total balance 9263.989999
# day 86: buy 1 unit at price 19.270000, total balance 9244.719999
# day 87, sell 1 unit at price 19.059999, investment -9.496677 %, total balance 9263.779998,
# day 88: buy 1 unit at price 18.990000, total balance 9244.789998
# day 89: buy 1 unit at price 18.770000, total balance 9226.019998
# day 90: buy 1 unit at price 18.690001, total balance 9207.329997
# day 91: buy 1 unit at price 18.559999, total balance 9188.769998
# day 92, sell 1 unit at price 18.750000, investment -11.095306 %, total balance 9207.519998,
# day 94: buy 1 unit at price 18.000000, total balance 9189.519998
# day 95: buy 1 unit at price 17.700001, total balance 9171.819997
# day 96, sell 1 unit at price 17.510000, investment -15.533044 %, total balance 9189.329997,
# day 97: buy 1 unit at price 17.360001, total balance 9171.969996
# day 98, sell 1 unit at price 17.260000, investment -16.779171 %, total balance 9189.229996,
# day 99: buy 1 unit at price 16.600000, total balance 9172.629996
# day 100: buy 1 unit at price 16.719999, total balance 9155.909997
# day 101: buy 1 unit at price 16.959999, total balance 9138.949998
# day 102: buy 1 unit at price 16.900000, total balance 9122.049998
# day 103: buy 1 unit at price 17.040001, total balance 9105.009997
# day 104: buy 1 unit at price 17.100000, total balance 9087.909997
# day 105: buy 1 unit at price 17.219999, total balance 9070.689998
# day 107: buy 1 unit at price 16.860001, total balance 9053.829997
# day 108: buy 1 unit at price 16.620001, total balance 9037.209996
# day 109, sell 1 unit at price 15.740000, investment -20.944249 %, total balance 9052.949996,
# day 110: buy 1 unit at price 16.139999, total balance 9036.809997
# day 111: buy 1 unit at price 16.090000, total balance 9020.719997
# day 112, sell 1 unit at price 15.280000, investment -22.983871 %, total balance 9035.999997,
# day 113: buy 1 unit at price 15.230000, total balance 9020.769997
# day 114: buy 1 unit at price 14.960000, total balance 9005.809997
# day 115: buy 1 unit at price 15.650000, total balance 8990.159997
# day 116, sell 1 unit at price 15.420000, investment -20.227625 %, total balance 9005.579997,
# day 117: buy 1 unit at price 15.600000, total balance 8989.979997
# day 118: buy 1 unit at price 15.480000, total balance 8974.499997
# day 119, sell 1 unit at price 15.310000, investment -20.960252 %, total balance 8989.809997,
# day 120: buy 1 unit at price 15.400000, total balance 8974.409997
# day 121: buy 1 unit at price 15.710000, total balance 8958.699997
# day 122: buy 1 unit at price 15.740000, total balance 8942.959997
# day 123: buy 1 unit at price 15.900000, total balance 8927.059997
# day 124: buy 1 unit at price 16.040001, total balance 8911.019996
# day 125: buy 1 unit at price 16.059999, total balance 8894.959997
# day 127: buy 1 unit at price 15.810000, total balance 8879.149997
# day 128: buy 1 unit at price 15.800000, total balance 8863.349997
# day 130: buy 1 unit at price 15.960000, total balance 8847.389997
# day 132: buy 1 unit at price 15.650000, total balance 8831.739997
# day 135: buy 1 unit at price 14.980000, total balance 8816.759997
# day 136: buy 1 unit at price 14.890000, total balance 8801.869997
# day 137: buy 1 unit at price 14.820000, total balance 8787.049997
# day 139, sell 1 unit at price 14.450000, investment -27.130610 %, total balance 8801.499997,
# day 141: buy 1 unit at price 14.790000, total balance 8786.709997
# day 142: buy 1 unit at price 14.810000, total balance 8771.899997
# day 143: buy 1 unit at price 14.820000, total balance 8757.079997
# day 145, sell 1 unit at price 14.400000, investment -27.601806 %, total balance 8771.479997,
# day 146: buy 1 unit at price 14.480000, total balance 8756.999997
# day 147: buy 1 unit at price 14.090000, total balance 8742.909997
# day 148: buy 1 unit at price 13.800000, total balance 8729.109997
# day 149, sell 1 unit at price 14.160000, investment -28.340081 %, total balance 8743.269997,
# day 150: buy 1 unit at price 14.280000, total balance 8728.989997
# day 151: buy 1 unit at price 14.180000, total balance 8714.809997
# day 152, sell 1 unit at price 14.340000, investment -27.281944 %, total balance 8729.149997,
# day 153: buy 1 unit at price 14.210000, total balance 8714.939997
# day 154: buy 1 unit at price 14.340000, total balance 8700.599997
# day 156: buy 1 unit at price 14.270000, total balance 8686.329997
# day 157: buy 1 unit at price 14.520000, total balance 8671.809997
# day 161: buy 1 unit at price 14.570000, total balance 8657.239997
# day 162: buy 1 unit at price 14.340000, total balance 8642.899997
# day 163: buy 1 unit at price 14.610000, total balance 8628.289997
# day 164, sell 1 unit at price 14.800000, investment -24.681934 %, total balance 8643.089997,
# day 165: buy 1 unit at price 14.730000, total balance 8628.359997
# day 166, sell 1 unit at price 15.030000, investment -24.962560 %, total balance 8643.389997,
# day 167, sell 1 unit at price 15.060000, investment -24.207352 %, total balance 8658.449997,
# day 169, sell 1 unit at price 15.260000, investment -22.222226 %, total balance 8673.709997,
# day 170, sell 1 unit at price 15.290000, investment -21.185567 %, total balance 8688.999997,
# day 171, sell 1 unit at price 15.360000, investment -21.832061 %, total balance 8704.359997,
# day 172, sell 1 unit at price 15.420000, investment -21.486758 %, total balance 8719.779997,
# day 173: buy 1 unit at price 15.510000, total balance 8704.269997
# day 174: buy 1 unit at price 15.430000, total balance 8688.839997
# day 175, sell 1 unit at price 15.670000, investment -20.376016 %, total balance 8704.509997,
# day 177: buy 1 unit at price 15.680000, total balance 8688.829997
# day 178, sell 1 unit at price 15.740000, investment -19.323424 %, total balance 8704.569997,
# day 180, sell 1 unit at price 15.450000, investment -20.971863 %, total balance 8720.019997,
# day 181: buy 1 unit at price 15.280000, total balance 8704.739997
# day 182: buy 1 unit at price 15.470000, total balance 8689.269997
# day 183, sell 1 unit at price 15.600000, investment -20.972644 %, total balance 8704.869997,
# day 185: buy 1 unit at price 15.340000, total balance 8689.529997
# day 186: buy 1 unit at price 15.240000, total balance 8674.289997
# day 187: buy 1 unit at price 15.170000, total balance 8659.119997
# day 188: buy 1 unit at price 15.330000, total balance 8643.789997
# day 191: buy 1 unit at price 15.050000, total balance 8628.739997
# day 192: buy 1 unit at price 14.880000, total balance 8613.859997
# day 193: buy 1 unit at price 14.860000, total balance 8598.999997
# day 194: buy 1 unit at price 15.050000, total balance 8583.949997
# day 196: buy 1 unit at price 14.660000, total balance 8569.289997
# day 197: buy 1 unit at price 14.780000, total balance 8554.509997
# day 198: buy 1 unit at price 14.650000, total balance 8539.859997
# day 199: buy 1 unit at price 14.510000, total balance 8525.349997
# day 200: buy 1 unit at price 14.370000, total balance 8510.979997
# day 202: buy 1 unit at price 14.350000, total balance 8496.629997
# day 203: buy 1 unit at price 14.200000, total balance 8482.429997
# day 204, sell 1 unit at price 14.050000, investment -26.975052 %, total balance 8496.479997,
# day 205, sell 1 unit at price 13.590000, investment -28.360566 %, total balance 8510.069997,
# day 206: buy 1 unit at price 13.550000, total balance 8496.519997
# day 207: buy 1 unit at price 13.500000, total balance 8483.019997
# day 208, sell 1 unit at price 13.080000, investment -31.589962 %, total balance 8496.099997,
# day 209: buy 1 unit at price 13.300000, total balance 8482.799997
# day 210: buy 1 unit at price 12.860000, total balance 8469.939997
# day 212: buy 1 unit at price 13.020000, total balance 8456.919997
# day 213: buy 1 unit at price 12.670000, total balance 8444.249997
# day 214: buy 1 unit at price 12.410000, total balance 8431.839997
# day 215: buy 1 unit at price 12.420000, total balance 8419.419997
# day 216, sell 1 unit at price 12.030000, investment -36.584077 %, total balance 8431.449997,
# day 217: buy 1 unit at price 12.330000, total balance 8419.119997
# day 218, sell 1 unit at price 12.520000, investment -31.208795 %, total balance 8431.639997,
# day 219: buy 1 unit at price 12.280000, total balance 8419.359997
# day 220: buy 1 unit at price 12.330000, total balance 8407.029997
# day 221: buy 1 unit at price 12.410000, total balance 8394.619997
# day 222: buy 1 unit at price 12.220000, total balance 8382.399997
# day 223, sell 1 unit at price 12.130000, investment -34.076087 %, total balance 8394.529997,
# day 224, sell 1 unit at price 11.870000, investment -36.251346 %, total balance 8406.399997,
# day 225: buy 1 unit at price 11.360000, total balance 8395.039997
# day 226: buy 1 unit at price 11.350000, total balance 8383.689997
# day 227, sell 1 unit at price 11.470000, investment -40.322578 %, total balance 8395.159997,
# day 228: buy 1 unit at price 11.770000, total balance 8383.389997
# day 229: buy 1 unit at price 11.750000, total balance 8371.639997
# day 230: buy 1 unit at price 11.680000, total balance 8359.959997
# day 231: buy 1 unit at price 11.540000, total balance 8348.419997
# day 233: buy 1 unit at price 11.370000, total balance 8337.049997
# day 234: buy 1 unit at price 11.340000, total balance 8325.709997
# day 235: buy 1 unit at price 11.050000, total balance 8314.659997
# day 236, sell 1 unit at price 11.250000, investment -40.539112 %, total balance 8325.909997,
# day 238, sell 1 unit at price 10.960000, investment -42.647831 %, total balance 8336.869997,
# day 239, sell 1 unit at price 11.210000, investment -41.000000 %, total balance 8348.079997,
# day 240: buy 1 unit at price 10.940000, total balance 8337.139997
# day 241, sell 1 unit at price 10.900000, investment -42.236357 %, total balance 8348.039997,
# day 242: buy 1 unit at price 11.260000, total balance 8336.779997
# day 243: buy 1 unit at price 11.480000, total balance 8325.299997
# day 244: buy 1 unit at price 11.380000, total balance 8313.919997
# day 245, sell 1 unit at price 11.170000, investment -41.792603 %, total balance 8325.089997,
# day 246: buy 1 unit at price 11.150000, total balance 8313.939997
# day 248: buy 1 unit at price 11.570000, total balance 8302.369997
# day 249: buy 1 unit at price 11.800000, total balance 8290.569997
# day 250: buy 1 unit at price 12.200000, total balance 8278.369997

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
